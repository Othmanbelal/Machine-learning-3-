# %% [markdown]
# group 48
#
# Othman bilal (Cid) Othmanb
#
# soheb Kanon  (Cid) Soheb

# %% [markdown]
# # Reinforcement learning and deep-learning
#
# ## General outline for this assingment
#
# * Q-learning, openai taxi problem
# * Deep Q-learning, control inverted pendelum
# * Image classification with pytorch for MNIST dataset
#
# This assignment combines the elements of comprehension and implementation. You will be responsible for coding in some sections, while in others, we will provide you with code to study.
#
# ### Q-Learning
#
# In this task, you will employ Q-learning to tackle decision-making in a grid world game. This will provide you with a foundational grasp of Q-learning and the principles of reinforcement learning.
#
# To set up the environment for the first two tasks, you'll need to install the required software. https://pypi.org/project/gymnasium/
#
# pip install gymnasium
#
#
# ### Deep Q-Learning
#
# Deep Q-learning combines neural networks with Q-learning. In this task, you're embarking on a rather ambitious journey. Your goal is to construct a neural network from the ground up and we will show how to apply it to a reinforcement learning problem. This endeavor aims to lay a solid foundation for your comprehension of neural networks and the inherent challenges they pose. This may well be one of the very few opportunities you'll have to create such a network from scratch, granting you insight into what transpires behind the scenes. Following this, you'll likely rely on libraries like PyTorch or TensorFlow, which abstract much of the mathematics.
#
# The core concept behind deep Q-learning involves approximating the Q-table with a neural network. However, as you'll soon discover, this endeavor is far from straightforward.
#
#
# ### CNN + dense with pytorch
#
# To wrap up, you will employ PyTorch to tackle an image classification problem, specifically the classification of handwritten numbers. In this segment, we will demonstrate how PyTorch can be used to construct neural networks. Your objective is to enhance the accuracy of this model to reach a minimum of 98%.
#
# You can easily install pytorch through (it is enough with just cpu support, if you have an nvidia graphics card you can try the cuda installation): https://pytorch.org/

# %% [markdown]
# # Q-Learning
#
# In reinforcement learning, the primary aim is to maximize future rewards. While this may not seem significantly different from supervised learning, the implications are profound. Consider the scenario where you want an AI to navigate a maze: at each time step, the AI can make a move in any valid direction. If you were to approach this as a regression problem, akin to supervised learning, you would need to know the precise solution for every step, which becomes infeasible for complex problems. Reinforcement learning simplifies the human side of the problem by using rewards. For instance, you can reward the AI only when it successfully solves the maze and allow the AI to explore freely. You don't instruct it on how to solve the maze directly but instead provide a reward for completing the task. The AI will then determine the most effective way to maximize the reward over the entire episode.
#
# If you want a robot to learn how to walk, you would provide rewards for moving in the correct direction and penalties if it falls, but you wouldn't explicitly instruct it on how to walk. This is the advantage of reinforcement learning.
#
# Q-learning represents one of the simplest versions of reinforcement learning.
#
# In this task, we will employ Q-learning to tackle the taxi problem, which is further described in https://gymnasium.farama.org/environments/toy_text/taxi/ and visualization is provided a few cells down. Short summary:
#
#
# >There are four designated pick-up and drop-off locations (Red, Green, Yellow and Blue) in the 5x5 grid world. The taxi starts off at a random square and the passenger at one of the designated locations.
# The goal is move the taxi to the passenger’s location, pick up the passenger, move to the passenger’s desired destination, and drop off the passenger. Once the passenger is dropped off, the episode ends.
# The player receives positive rewards for successfully dropping-off the passenger at the correct location. Negative rewards for incorrect attempts to pick-up/drop-off passenger and for each step where another reward is not received.
#
# Let's start by importing the necessary libraries

# %%
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

# %% [markdown]
# The code below visulizes the environment with random actions, the goal will be to create a policy that chooses actions.

# %%
env_render = gym.make("Taxi-v3", render_mode='human') # create environment with rendering 
state, _ = env_render.reset() # initiate the environment
done = False
i = 0
while not done:
    action = env_render.action_space.sample()  # Samples random actions from our environment. 
    new_state, reward, terminated, truncated, _ = env_render.step(action) # takes as step in our environment
    done = terminated or truncated # checks if we have reached our goal or timed out
    state = new_state # updates the current state.
    if i > 20: # End after 20 steps
        done = True
    i+=1
env_render.close()

# %% [markdown]
# ## The Q-learning algorithm
#
# In Q-learning we want to learn a look-up table that for every state and action has the future discounted reward. It is initialized with zeros.
#
# | State  | a1  | a2  | a3  | a4 |
# |---|---|---|---|---|
# | 1  | 0  | 0  | 0 | 0  |
# | 2  | 0  | 0  | 0 | 0  |
# | ...  | ...  | ...  | ... | ... |
# | N  | 0  | 0  | 0 | 0  |
#
# The training then updates this table to the correct values. It might look something like:
#
# | State  | a1  | a2  | a3  | a4 |
# |---|---|---|---|---|
# | 1  | 0.1  | -5  | 1 | 0.4  |
# | 2  | -1  | -2  | 0 | 4  |
# | ...  | ...  | ...  | ... | ... |
# | N  | 1  | 2  | -2 | 1  |
#
# List of some terms in the feild of Q-learning:
# * State - A state in our environment is a representation of all the information available to make a decision. At time step "t," we have the state "s_t." In the case of the taxi problem, there are 500 different states. Each state is an integer within the range of 0 to 500, and it represents:
#     * 25 different taxi locations
#     * 5 passenger locations
#     * 4 possible destinations
# * Markov decision process (MDP) - Q-learning is an algorithm designed to solve problems involving finite discrete Markov decision processes (MDPs) https://en.wikipedia.org/wiki/Markov_decision_process.
# * Action - The actions is how we transition between states, at time step $t$ the action $a_t$ takes us to $s_{t+1}$. In this case we have 6 possible actions:
#     * 0: Move south (down)
#     * 1: Move north (up)
#     * 2: Move east (right)
#     * 3: Move west (left)
#     * 4: Pickup passenger
#     * 5: Drop off passenger
# * Reward - In reinforcement learning, the system provides rewards and penalties to guide the learning process. When the actor successfully completes a task or makes a correct move, a reward $r$ is given. Conversely, penalties can be imposed for suboptimal or incorrect actions. These rewards and penalties serve as the means to influence and shape what the algorithm attempts to learn and optimize. The algorithm aims to maximize the cumulative rewards over time by making decisions that lead to higher overall rewards and fewer penalties.
# * Q-table - The q table contains for every state (s) and action (a) the expected future discounted reward. Often written as Q(s, a), see above.
# * Policy - How do we choose our action, Q(s, a) outputs how good a action is but not directly which action to choose.
# * Greedy policy - For a state choose the action that has the highest expected reward.
# * Epsilon greedy policy - During training allow for exploration by having a probability of choosing a random action instead of greedy. Exploration is necessary for learning, without it the learning can get stuck in the same solution.
# * Episode - One espisode is the agient interacting with the environment from start to finish or termination i.e. a timeseries of states and actions.
#
# The q-table can be initated with zeros. It can be updated as:
#
# $Q(s_t, a_t) = (1- \alpha)Q(s_t, a_t) + \alpha(r_t + \gamma \underbrace{\max}_{a} Q(s_{t+1}, a))$
#
# where $\alpha$ is the learning rate and $\gamma$ is the dicount factor. For training, we want a policy that both explores new paths while at the same time exploits the current best solution. The solution is an epsilon greedy policy. There is more information at https://en.wikipedia.org/wiki/Q-learning. Also notice that we never update the Q values for the goal state, as the episode will terminate upon reaching the goal. The epsilon greedy policy:
#
# $a \begin{cases} random & \textrm{With probability } \epsilon \\
#                 greedy &  \textrm{With probability } 1 - \epsilon \end{cases}$
#
# Where $\epsilon$ is ussually decresing with traning, here is exponential decay.
#
# $ \epsilon = \epsilon_{\textrm{min}} + (\epsilon_{\textrm{max}} -\epsilon_{\textrm{min}}) e^{- \lambda i_e}$
#
# where $\epsilon_{\textrm{min}}$ is the minimum value of $\epsilon$, i.e. we allways want some exploration, otherwise we wont learn anything new. $\epsilon_{\textrm{max}}$ usually set to $1$, how much exploration to start of with. $\lambda$ is the decay rate, how fast should we decreese the amount of exploration. $i_e$ is how many episodes we have trained on.
#
# Next we can check how many state and actions our environment has.

# %%
env = gym.make("Taxi-v3")
num_states = env.observation_space.n
num_actions = env.action_space.n
print('Number of states', num_states, 'and number of actions', num_actions)
# Out:
# Number of states 500 and number of actions 6

# %% [markdown]
# We define our hyper parameters.

# %%
# Hyperparameters
learning_rate = 0.1 # aplha in our q-learning update
discount_factor = 0.99 # gamma
epsilon = 1.0 # epsilon
epsilon_max = 1.0 # epsilon max
epsilon_min = 0.01 # epsilon min
epsilon_lambda = 0.01 # lambda
num_episodes = 5000

# %% [markdown]
# ## Exersice 1.1: Q-learning
#
# Here the task is to implement the Q-learning algorithm.

# %%
# Initiate q-table

q_table = np.zeros((num_states, num_actions))


# Q-learning algorithm
for episode in range(num_episodes):
    state, info = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        # Calculate action with exploration-exploitation trade-off
        if np.random.rand() < epsilon:
            # Explore by selecting a random action
            action = env.action_space.sample()
        else:
            # Exploit by selecting the action with the highest Q-value
            action = np.argmax(q_table[state, :])
        
        
        # step 
        new_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        
        # Q-value update
        q_table[state, action] = (1- learning_rate)* q_table[state, action] + learning_rate * (reward + discount_factor * np.max(q_table[new_state, :]))
        
        
        total_reward += reward
        state = new_state
    
    # Decay exploration probability (epsilon)
    
    #epsilon = max(epsilon_min, epsilon_max -((epsilon_max - epsilon_min) / num_episodes)) wtf Othman
    epsilon = max(epsilon_min, epsilon * np.exp(-epsilon_lambda * episode))

    print(f"Episode: {episode+1}, Total Reward: {total_reward}")
# Out:
# Episode: 1, Total Reward: -704
# Episode: 2, Total Reward: -812
# Episode: 3, Total Reward: -785
# Episode: 4, Total Reward: -749
# Episode: 5, Total Reward: -767
# Episode: 6, Total Reward: -767
# Episode: 7, Total Reward: -677
# Episode: 8, Total Reward: -704
# Episode: 9, Total Reward: -749
# Episode: 10, Total Reward: -740
# Episode: 11, Total Reward: -686
# Episode: 12, Total Reward: -596
# Episode: 13, Total Reward: -596
# Episode: 14, Total Reward: -614
# Episode: 15, Total Reward: -668
# Episode: 16, Total Reward: -488
# Episode: 17, Total Reward: -497
# Episode: 18, Total Reward: -569
# Episode: 19, Total Reward: -416
# Episode: 20, Total Reward: -420
# Episode: 21, Total Reward: -614
# Episode: 22, Total Reward: -245
# Episode: 23, Total Reward: -605
# Episode: 24, Total Reward: -497
# Episode: 25, Total Reward: -345
# Episode: 26, Total Reward: -380
# Episode: 27, Total Reward: -105
# Episode: 28, Total Reward: -308
# Episode: 29, Total Reward: -142
# Episode: 30, Total Reward: -218
# Episode: 31, Total Reward: -299
# Episode: 32, Total Reward: -209
# Episode: 33, Total Reward: -317
# Episode: 34, Total Reward: -209
# Episode: 35, Total Reward: -326
# Episode: 36, Total Reward: -200
# Episode: 37, Total Reward: -209
# Episode: 38, Total Reward: -245
# Episode: 39, Total Reward: -200
# Episode: 40, Total Reward: -218
# Episode: 41, Total Reward: -245
# Episode: 42, Total Reward: -479
# Episode: 43, Total Reward: -209
# Episode: 44, Total Reward: -41
# Episode: 45, Total Reward: -416
# Episode: 46, Total Reward: -371
# Episode: 47, Total Reward: -254
# Episode: 48, Total Reward: -335
# Episode: 49, Total Reward: -290
# Episode: 50, Total Reward: -200
# Episode: 51, Total Reward: -200
# Episode: 52, Total Reward: -236
# Episode: 53, Total Reward: -228
# Episode: 54, Total Reward: -290
# Episode: 55, Total Reward: -200
# Episode: 56, Total Reward: -84
# Episode: 57, Total Reward: -209
# Episode: 58, Total Reward: -98
# Episode: 59, Total Reward: -94
# Episode: 60, Total Reward: -209
# Episode: 61, Total Reward: -200
# Episode: 62, Total Reward: -200
# Episode: 63, Total Reward: -227
# Episode: 64, Total Reward: -398
# Episode: 65, Total Reward: -112
# Episode: 66, Total Reward: -200
# Episode: 67, Total Reward: -326
# Episode: 68, Total Reward: -218
# Episode: 69, Total Reward: -200
# Episode: 70, Total Reward: -227
# Episode: 71, Total Reward: -83
# Episode: 72, Total Reward: -209
# Episode: 73, Total Reward: -236
# Episode: 74, Total Reward: -353
# Episode: 75, Total Reward: -190
# Episode: 76, Total Reward: -263
# Episode: 77, Total Reward: -200
# Episode: 78, Total Reward: -209
# Episode: 79, Total Reward: -227
# Episode: 80, Total Reward: -209
# Episode: 81, Total Reward: -210
# Episode: 82, Total Reward: -200
# Episode: 83, Total Reward: -281
# Episode: 84, Total Reward: -97
# Episode: 85, Total Reward: -200
# Episode: 86, Total Reward: -218
# Episode: 87, Total Reward: -115
# Episode: 88, Total Reward: -200
# Episode: 89, Total Reward: -151
# Episode: 90, Total Reward: -209
# Episode: 91, Total Reward: -200
# Episode: 92, Total Reward: -159
# Episode: 93, Total Reward: -209
# Episode: 94, Total Reward: -142
# Episode: 95, Total Reward: -162
# Episode: 96, Total Reward: -209
# Episode: 97, Total Reward: -200
# Episode: 98, Total Reward: -218
# Episode: 99, Total Reward: -30
# Episode: 100, Total Reward: -497
# Episode: 101, Total Reward: -326
# Episode: 102, Total Reward: -470
# Episode: 103, Total Reward: -255
# Episode: 104, Total Reward: -362
# Episode: 105, Total Reward: -64
# Episode: 106, Total Reward: -326
# Episode: 107, Total Reward: -131
# Episode: 108, Total Reward: -218
# Episode: 109, Total Reward: -61
# Episode: 110, Total Reward: -235
# Episode: 111, Total Reward: -479
# Episode: 112, Total Reward: -218
# Episode: 113, Total Reward: -148
# Episode: 114, Total Reward: -218
# Episode: 115, Total Reward: -209
# Episode: 116, Total Reward: -218
# Episode: 117, Total Reward: -290
# Episode: 118, Total Reward: -197
# Episode: 119, Total Reward: -416
# Episode: 120, Total Reward: -281
# Episode: 121, Total Reward: -236
# Episode: 122, Total Reward: -227
# Episode: 123, Total Reward: -200
# Episode: 124, Total Reward: -218
# Episode: 125, Total Reward: -82
# Episode: 126, Total Reward: -200
# Episode: 127, Total Reward: -263
# Episode: 128, Total Reward: -34
# Episode: 129, Total Reward: -281
# Episode: 130, Total Reward: -43
# Episode: 131, Total Reward: -272
# Episode: 132, Total Reward: -141
# Episode: 133, Total Reward: -344
# Episode: 134, Total Reward: -160
# Episode: 135, Total Reward: -209
# Episode: 136, Total Reward: -380
# Episode: 137, Total Reward: -187
# Episode: 138, Total Reward: -115
# Episode: 139, Total Reward: -209
# Episode: 140, Total Reward: -106
# Episode: 141, Total Reward: -186
# Episode: 142, Total Reward: -236
# Episode: 143, Total Reward: -344
# Episode: 144, Total Reward: -209
# Episode: 145, Total Reward: -258
# Episode: 146, Total Reward: -28
# Episode: 147, Total Reward: -234
# Episode: 148, Total Reward: -140
# Episode: 149, Total Reward: -78
# Episode: 150, Total Reward: -240
# Episode: 151, Total Reward: -272
# Episode: 152, Total Reward: -131
# Episode: 153, Total Reward: -200
# Episode: 154, Total Reward: -245
# Episode: 155, Total Reward: -209
# Episode: 156, Total Reward: -4
# Episode: 157, Total Reward: -91
# Episode: 158, Total Reward: -180
# Episode: 159, Total Reward: -42
# Episode: 160, Total Reward: -70
# Episode: 161, Total Reward: -200
# Episode: 162, Total Reward: -132
# Episode: 163, Total Reward: -86
# Episode: 164, Total Reward: -102
# Episode: 165, Total Reward: -50
# Episode: 166, Total Reward: -87
# Episode: 167, Total Reward: -211
# Episode: 168, Total Reward: -227
# Episode: 169, Total Reward: -200
# Episode: 170, Total Reward: -326
# Episode: 171, Total Reward: -175
# Episode: 172, Total Reward: -317
# Episode: 173, Total Reward: -64
# Episode: 174, Total Reward: -218
# Episode: 175, Total Reward: -209
# Episode: 176, Total Reward: -91
# Episode: 177, Total Reward: -18
# Episode: 178, Total Reward: -299
# Episode: 179, Total Reward: -416
# Episode: 180, Total Reward: -326
# Episode: 181, Total Reward: -114
# Episode: 182, Total Reward: -59
# Episode: 183, Total Reward: -200
# Episode: 184, Total Reward: -221
# Episode: 185, Total Reward: -209
# Episode: 186, Total Reward: -290
# Episode: 187, Total Reward: -209
# Episode: 188, Total Reward: -57
# Episode: 189, Total Reward: -200
# Episode: 190, Total Reward: -317
# Episode: 191, Total Reward: -102
# Episode: 192, Total Reward: -200
# Episode: 193, Total Reward: -56
# Episode: 194, Total Reward: -216
# Episode: 195, Total Reward: -245
# Episode: 196, Total Reward: -105
# Episode: 197, Total Reward: -70
# Episode: 198, Total Reward: -362
# Episode: 199, Total Reward: -425
# Episode: 200, Total Reward: -142
# Episode: 201, Total Reward: -272
# Episode: 202, Total Reward: -20
# Episode: 203, Total Reward: -163
# Episode: 204, Total Reward: -209
# Episode: 205, Total Reward: -39
# Episode: 206, Total Reward: -37
# Episode: 207, Total Reward: -146
# Episode: 208, Total Reward: -59
# Episode: 209, Total Reward: -83
# Episode: 210, Total Reward: -335
# Episode: 211, Total Reward: -154
# Episode: 212, Total Reward: -353
# Episode: 213, Total Reward: -147
# Episode: 214, Total Reward: -165
# Episode: 215, Total Reward: -17
# Episode: 216, Total Reward: -115
# Episode: 217, Total Reward: -413
# Episode: 218, Total Reward: -86
# Episode: 219, Total Reward: -389
# Episode: 220, Total Reward: -11
# Episode: 221, Total Reward: -218
# Episode: 222, Total Reward: -15
# Episode: 223, Total Reward: -342
# Episode: 224, Total Reward: 7
# Episode: 225, Total Reward: -398
# Episode: 226, Total Reward: -263
# Episode: 227, Total Reward: -87
# Episode: 228, Total Reward: -362
# Episode: 229, Total Reward: -309
# Episode: 230, Total Reward: -128
# Episode: 231, Total Reward: -272
# Episode: 232, Total Reward: -75
# Episode: 233, Total Reward: -15
# Episode: 234, Total Reward: -37
# Episode: 235, Total Reward: -371
# Episode: 236, Total Reward: -182
# Episode: 237, Total Reward: -227
# Episode: 238, Total Reward: -209
# Episode: 239, Total Reward: -216
# Episode: 240, Total Reward: -151
# Episode: 241, Total Reward: -184
# Episode: 242, Total Reward: -37
# Episode: 243, Total Reward: -194
# Episode: 244, Total Reward: -118
# Episode: 245, Total Reward: -172
# Episode: 246, Total Reward: -39
# Episode: 247, Total Reward: -184
# Episode: 248, Total Reward: -27
# Episode: 249, Total Reward: -94
# Episode: 250, Total Reward: -125
# Episode: 251, Total Reward: -70
# Episode: 252, Total Reward: -168
# Episode: 253, Total Reward: -171
# Episode: 254, Total Reward: -159
# Episode: 255, Total Reward: -107
# Episode: 256, Total Reward: -209
# Episode: 257, Total Reward: -128
# Episode: 258, Total Reward: -201
# Episode: 259, Total Reward: -124
# Episode: 260, Total Reward: -196
# Episode: 261, Total Reward: -202
# Episode: 262, Total Reward: -96
# Episode: 263, Total Reward: -191
# Episode: 264, Total Reward: -166
# Episode: 265, Total Reward: -57
# Episode: 266, Total Reward: -164
# Episode: 267, Total Reward: -236
# Episode: 268, Total Reward: -326
# Episode: 269, Total Reward: -100
# Episode: 270, Total Reward: -146
# Episode: 271, Total Reward: -183
# Episode: 272, Total Reward: -132
# Episode: 273, Total Reward: -208
# Episode: 274, Total Reward: 12
# Episode: 275, Total Reward: -29
# Episode: 276, Total Reward: -86
# Episode: 277, Total Reward: -110
# Episode: 278, Total Reward: -265
# Episode: 279, Total Reward: -63
# Episode: 280, Total Reward: -126
# Episode: 281, Total Reward: -245
# Episode: 282, Total Reward: -200
# Episode: 283, Total Reward: -74
# Episode: 284, Total Reward: -96
# Episode: 285, Total Reward: -14
# Episode: 286, Total Reward: -344
# Episode: 287, Total Reward: -30
# Episode: 288, Total Reward: -25
# Episode: 289, Total Reward: -77
# Episode: 290, Total Reward: -200
# Episode: 291, Total Reward: -6
# Episode: 292, Total Reward: -132
# Episode: 293, Total Reward: -10
# Episode: 294, Total Reward: -299
# Episode: 295, Total Reward: -195
# Episode: 296, Total Reward: -69
# Episode: 297, Total Reward: -93
# Episode: 298, Total Reward: -80
# Episode: 299, Total Reward: -47
# Episode: 300, Total Reward: -126
# Episode: 301, Total Reward: -308
# Episode: 302, Total Reward: -105
# Episode: 303, Total Reward: -73
# Episode: 304, Total Reward: -116
# Episode: 305, Total Reward: -188
# Episode: 306, Total Reward: -21
# Episode: 307, Total Reward: -80
# Episode: 308, Total Reward: -205
# Episode: 309, Total Reward: -32
# Episode: 310, Total Reward: -261
# Episode: 311, Total Reward: -21
# Episode: 312, Total Reward: -48
# Episode: 313, Total Reward: -191
# Episode: 314, Total Reward: -70
# Episode: 315, Total Reward: -297
# Episode: 316, Total Reward: -34
# Episode: 317, Total Reward: -4
# Episode: 318, Total Reward: -15
# Episode: 319, Total Reward: 10
# Episode: 320, Total Reward: -186
# Episode: 321, Total Reward: -107
# Episode: 322, Total Reward: -209
# Episode: 323, Total Reward: -4
# Episode: 324, Total Reward: -171
# Episode: 325, Total Reward: -55
# Episode: 326, Total Reward: -80
# Episode: 327, Total Reward: -95
# Episode: 328, Total Reward: -168
# Episode: 329, Total Reward: -163
# Episode: 330, Total Reward: 14
# Episode: 331, Total Reward: -172
# Episode: 332, Total Reward: -213
# Episode: 333, Total Reward: -74
# Episode: 334, Total Reward: -77
# Episode: 335, Total Reward: -362
# Episode: 336, Total Reward: -199
# Episode: 337, Total Reward: -113
# Episode: 338, Total Reward: -146
# Episode: 339, Total Reward: -90
# Episode: 340, Total Reward: -184
# Episode: 341, Total Reward: -112
# Episode: 342, Total Reward: -155
# Episode: 343, Total Reward: -150
# Episode: 344, Total Reward: -256
# Episode: 345, Total Reward: 0
# Episode: 346, Total Reward: -40
# Episode: 347, Total Reward: -161
# Episode: 348, Total Reward: -159
# Episode: 349, Total Reward: -8
# Episode: 350, Total Reward: -282
# Episode: 351, Total Reward: -129
# Episode: 352, Total Reward: -134
# Episode: 353, Total Reward: -220
# Episode: 354, Total Reward: -233
# Episode: 355, Total Reward: -25
# Episode: 356, Total Reward: -250
# Episode: 357, Total Reward: -182
# Episode: 358, Total Reward: -160
# Episode: 359, Total Reward: -220
# Episode: 360, Total Reward: -150
# Episode: 361, Total Reward: -171
# Episode: 362, Total Reward: -326
# Episode: 363, Total Reward: -189
# Episode: 364, Total Reward: -93
# Episode: 365, Total Reward: -236
# Episode: 366, Total Reward: -109
# Episode: 367, Total Reward: -81
# Episode: 368, Total Reward: -148
# Episode: 369, Total Reward: -181
# Episode: 370, Total Reward: -18
# Episode: 371, Total Reward: -113
# Episode: 372, Total Reward: -200
# Episode: 373, Total Reward: 10
# Episode: 374, Total Reward: -155
# Episode: 375, Total Reward: -119
# Episode: 376, Total Reward: -107
# Episode: 377, Total Reward: -136
# Episode: 378, Total Reward: -66
# Episode: 379, Total Reward: -123
# Episode: 380, Total Reward: -160
# Episode: 381, Total Reward: -106
# Episode: 382, Total Reward: -109
# Episode: 383, Total Reward: -131
# Episode: 384, Total Reward: -23
# Episode: 385, Total Reward: -15
# Episode: 386, Total Reward: -141
# Episode: 387, Total Reward: -39
# Episode: 388, Total Reward: -18
# Episode: 389, Total Reward: -170
# Episode: 390, Total Reward: -156
# Episode: 391, Total Reward: -27
# Episode: 392, Total Reward: -15
# Episode: 393, Total Reward: -166
# Episode: 394, Total Reward: -117
# Episode: 395, Total Reward: -149
# Episode: 396, Total Reward: -31
# Episode: 397, Total Reward: -13
# Episode: 398, Total Reward: -170
# Episode: 399, Total Reward: -90
# Episode: 400, Total Reward: -143
# Episode: 401, Total Reward: -42
# Episode: 402, Total Reward: -69
# Episode: 403, Total Reward: -69
# Episode: 404, Total Reward: -227
# Episode: 405, Total Reward: -13
# Episode: 406, Total Reward: 3
# Episode: 407, Total Reward: -211
# Episode: 408, Total Reward: -54
# Episode: 409, Total Reward: -31
# Episode: 410, Total Reward: -99
# Episode: 411, Total Reward: 14
# Episode: 412, Total Reward: -10
# Episode: 413, Total Reward: -166
# Episode: 414, Total Reward: -30
# Episode: 415, Total Reward: -26
# Episode: 416, Total Reward: -17
# Episode: 417, Total Reward: -221
# Episode: 418, Total Reward: -117
# Episode: 419, Total Reward: -15
# Episode: 420, Total Reward: 5
# Episode: 421, Total Reward: -19
# Episode: 422, Total Reward: -317
# Episode: 423, Total Reward: -73
# Episode: 424, Total Reward: -362
# Episode: 425, Total Reward: 12
# Episode: 426, Total Reward: -217
# Episode: 427, Total Reward: -470
# Episode: 428, Total Reward: -124
# Episode: 429, Total Reward: -203
# Episode: 430, Total Reward: -24
# Episode: 431, Total Reward: -102
# Episode: 432, Total Reward: -187
# Episode: 433, Total Reward: -3
# Episode: 434, Total Reward: -130
# Episode: 435, Total Reward: 8
# Episode: 436, Total Reward: -99
# Episode: 437, Total Reward: 10
# Episode: 438, Total Reward: -124
# Episode: 439, Total Reward: -71
# Episode: 440, Total Reward: -159
# Episode: 441, Total Reward: -66
# Episode: 442, Total Reward: -23
# Episode: 443, Total Reward: -13
# Episode: 444, Total Reward: -24
# Episode: 445, Total Reward: -40
# Episode: 446, Total Reward: -26
# Episode: 447, Total Reward: -118
# Episode: 448, Total Reward: 12
# Episode: 449, Total Reward: 11
# Episode: 450, Total Reward: 14
# Episode: 451, Total Reward: -45
# Episode: 452, Total Reward: -76
# Episode: 453, Total Reward: -37
# Episode: 454, Total Reward: -71
# Episode: 455, Total Reward: -94
# Episode: 456, Total Reward: -132
# Episode: 457, Total Reward: -127
# Episode: 458, Total Reward: -120
# Episode: 459, Total Reward: -67
# Episode: 460, Total Reward: -120
# Episode: 461, Total Reward: -236
# Episode: 462, Total Reward: -69
# Episode: 463, Total Reward: -78
# Episode: 464, Total Reward: -14
# Episode: 465, Total Reward: -78
# Episode: 466, Total Reward: 7
# Episode: 467, Total Reward: -43
# Episode: 468, Total Reward: -59
# Episode: 469, Total Reward: -100
# Episode: 470, Total Reward: -20
# Episode: 471, Total Reward: -12
# Episode: 472, Total Reward: -200
# Episode: 473, Total Reward: -27
# Episode: 474, Total Reward: -63
# Episode: 475, Total Reward: 6
# Episode: 476, Total Reward: -229
# Episode: 477, Total Reward: -135
# Episode: 478, Total Reward: 0
# Episode: 479, Total Reward: -137
# Episode: 480, Total Reward: -61
# Episode: 481, Total Reward: -12
# Episode: 482, Total Reward: -63
# Episode: 483, Total Reward: 10
# Episode: 484, Total Reward: 7
# Episode: 485, Total Reward: -19
# Episode: 486, Total Reward: -20
# Episode: 487, Total Reward: -122
# Episode: 488, Total Reward: -94
# Episode: 489, Total Reward: -51
# Episode: 490, Total Reward: 4
# Episode: 491, Total Reward: -84
# Episode: 492, Total Reward: 0
# Episode: 493, Total Reward: -178
# Episode: 494, Total Reward: -8
# Episode: 495, Total Reward: -107
# Episode: 496, Total Reward: 10
# Episode: 497, Total Reward: -41
# Episode: 498, Total Reward: -198
# Episode: 499, Total Reward: -321
# Episode: 500, Total Reward: -118
# Episode: 501, Total Reward: -49
# Episode: 502, Total Reward: -173
# Episode: 503, Total Reward: 13
# Episode: 504, Total Reward: -96
# Episode: 505, Total Reward: -172
# Episode: 506, Total Reward: -51
# Episode: 507, Total Reward: -184
# Episode: 508, Total Reward: -120
# Episode: 509, Total Reward: -175
# Episode: 510, Total Reward: -140
# Episode: 511, Total Reward: 11
# Episode: 512, Total Reward: -22
# Episode: 513, Total Reward: 13
# Episode: 514, Total Reward: -59
# Episode: 515, Total Reward: -93
# Episode: 516, Total Reward: -401
# Episode: 517, Total Reward: -55
# Episode: 518, Total Reward: 10
# Episode: 519, Total Reward: 7
# Episode: 520, Total Reward: -134
# Episode: 521, Total Reward: -6
# Episode: 522, Total Reward: -30
# Episode: 523, Total Reward: 14
# Episode: 524, Total Reward: 9
# Episode: 525, Total Reward: -122
# Episode: 526, Total Reward: -92
# Episode: 527, Total Reward: -1
# Episode: 528, Total Reward: -145
# Episode: 529, Total Reward: -11
# Episode: 530, Total Reward: -136
# Episode: 531, Total Reward: -34
# Episode: 532, Total Reward: -82
# Episode: 533, Total Reward: -156
# Episode: 534, Total Reward: -34
# Episode: 535, Total Reward: -49
# Episode: 536, Total Reward: -90
# Episode: 537, Total Reward: -75
# Episode: 538, Total Reward: -72
# Episode: 539, Total Reward: 11
# Episode: 540, Total Reward: -39
# Episode: 541, Total Reward: -90
# Episode: 542, Total Reward: -42
# Episode: 543, Total Reward: -22
# Episode: 544, Total Reward: -91
# Episode: 545, Total Reward: -66
# Episode: 546, Total Reward: -119
# Episode: 547, Total Reward: -56
# Episode: 548, Total Reward: -38
# Episode: 549, Total Reward: -15
# Episode: 550, Total Reward: -174
# Episode: 551, Total Reward: -39
# Episode: 552, Total Reward: -6
# Episode: 553, Total Reward: -38
# Episode: 554, Total Reward: -63
# Episode: 555, Total Reward: -170
# Episode: 556, Total Reward: -66
# Episode: 557, Total Reward: 7
# Episode: 558, Total Reward: -262
# Episode: 559, Total Reward: -3
# Episode: 560, Total Reward: 1
# Episode: 561, Total Reward: -20
# Episode: 562, Total Reward: -178
# Episode: 563, Total Reward: -19
# Episode: 564, Total Reward: -108
# Episode: 565, Total Reward: 4
# Episode: 566, Total Reward: 7
# Episode: 567, Total Reward: -4
# Episode: 568, Total Reward: -13
# Episode: 569, Total Reward: 6
# Episode: 570, Total Reward: -218
# Episode: 571, Total Reward: 1
# Episode: 572, Total Reward: -90
# Episode: 573, Total Reward: -101
# Episode: 574, Total Reward: -85
# Episode: 575, Total Reward: 10
# Episode: 576, Total Reward: -74
# Episode: 577, Total Reward: -104
# Episode: 578, Total Reward: -58
# Episode: 579, Total Reward: -65
# Episode: 580, Total Reward: -61
# Episode: 581, Total Reward: 9
# Episode: 582, Total Reward: -53
# Episode: 583, Total Reward: -68
# Episode: 584, Total Reward: -191
# Episode: 585, Total Reward: -137
# Episode: 586, Total Reward: -19
# Episode: 587, Total Reward: 12
# Episode: 588, Total Reward: -101
# Episode: 589, Total Reward: -11
# Episode: 590, Total Reward: 14
# Episode: 591, Total Reward: -12
# Episode: 592, Total Reward: -49
# Episode: 593, Total Reward: 12
# Episode: 594, Total Reward: -49
# Episode: 595, Total Reward: -102
# Episode: 596, Total Reward: -96
# Episode: 597, Total Reward: -2
# Episode: 598, Total Reward: -63
# Episode: 599, Total Reward: -36
# Episode: 600, Total Reward: -116
# Episode: 601, Total Reward: 9
# Episode: 602, Total Reward: -80
# Episode: 603, Total Reward: -188
# Episode: 604, Total Reward: -64
# Episode: 605, Total Reward: -131
# Episode: 606, Total Reward: 1
# Episode: 607, Total Reward: -146
# Episode: 608, Total Reward: -145
# Episode: 609, Total Reward: -42
# Episode: 610, Total Reward: 12
# Episode: 611, Total Reward: 4
# Episode: 612, Total Reward: -72
# Episode: 613, Total Reward: -17
# Episode: 614, Total Reward: 12
# Episode: 615, Total Reward: -52
# Episode: 616, Total Reward: -39
# Episode: 617, Total Reward: -70
# Episode: 618, Total Reward: -174
# Episode: 619, Total Reward: -59
# Episode: 620, Total Reward: -1
# Episode: 621, Total Reward: -6
# Episode: 622, Total Reward: 13
# Episode: 623, Total Reward: 11
# Episode: 624, Total Reward: -80
# Episode: 625, Total Reward: -4
# Episode: 626, Total Reward: 10
# Episode: 627, Total Reward: 14
# Episode: 628, Total Reward: 12
# Episode: 629, Total Reward: 9
# Episode: 630, Total Reward: -20
# Episode: 631, Total Reward: -40
# Episode: 632, Total Reward: -79
# Episode: 633, Total Reward: -12
# Episode: 634, Total Reward: -6
# Episode: 635, Total Reward: -32
# Episode: 636, Total Reward: 3
# Episode: 637, Total Reward: -23
# Episode: 638, Total Reward: -97
# Episode: 639, Total Reward: -12
# Episode: 640, Total Reward: -8
# Episode: 641, Total Reward: -18
# Episode: 642, Total Reward: -54
# Episode: 643, Total Reward: -35
# Episode: 644, Total Reward: 5
# Episode: 645, Total Reward: 9
# Episode: 646, Total Reward: -3
# Episode: 647, Total Reward: 10
# Episode: 648, Total Reward: -92
# Episode: 649, Total Reward: -3
# Episode: 650, Total Reward: -129
# Episode: 651, Total Reward: -87
# Episode: 652, Total Reward: 14
# Episode: 653, Total Reward: -88
# Episode: 654, Total Reward: -78
# Episode: 655, Total Reward: -61
# Episode: 656, Total Reward: 11
# Episode: 657, Total Reward: 12
# Episode: 658, Total Reward: 12
# Episode: 659, Total Reward: 12
# Episode: 660, Total Reward: 11
# Episode: 661, Total Reward: 13
# Episode: 662, Total Reward: 10
# Episode: 663, Total Reward: -59
# Episode: 664, Total Reward: 1
# Episode: 665, Total Reward: -2
# Episode: 666, Total Reward: -14
# Episode: 667, Total Reward: -56
# Episode: 668, Total Reward: -1
# Episode: 669, Total Reward: -7
# Episode: 670, Total Reward: -14
# Episode: 671, Total Reward: 11
# Episode: 672, Total Reward: 12
# Episode: 673, Total Reward: 9
# Episode: 674, Total Reward: 5
# Episode: 675, Total Reward: -23
# Episode: 676, Total Reward: 0
# Episode: 677, Total Reward: -34
# Episode: 678, Total Reward: 4
# Episode: 679, Total Reward: -19
# Episode: 680, Total Reward: -55
# Episode: 681, Total Reward: -173
# Episode: 682, Total Reward: -38
# Episode: 683, Total Reward: 7
# Episode: 684, Total Reward: 10
# Episode: 685, Total Reward: -140
# Episode: 686, Total Reward: -44
# Episode: 687, Total Reward: -33
# Episode: 688, Total Reward: -15
# Episode: 689, Total Reward: -25
# Episode: 690, Total Reward: -5
# Episode: 691, Total Reward: -14
# Episode: 692, Total Reward: -18
# Episode: 693, Total Reward: 6
# Episode: 694, Total Reward: -109
# Episode: 695, Total Reward: -77
# Episode: 696, Total Reward: -36
# Episode: 697, Total Reward: -36
# Episode: 698, Total Reward: 1
# Episode: 699, Total Reward: 11
# Episode: 700, Total Reward: -93
# Episode: 701, Total Reward: -111
# Episode: 702, Total Reward: 12
# Episode: 703, Total Reward: -122
# Episode: 704, Total Reward: 7
# Episode: 705, Total Reward: -189
# Episode: 706, Total Reward: -1
# Episode: 707, Total Reward: -251
# Episode: 708, Total Reward: -24
# Episode: 709, Total Reward: -3
# Episode: 710, Total Reward: 10
# Episode: 711, Total Reward: -17
# Episode: 712, Total Reward: -16
# Episode: 713, Total Reward: -5
# Episode: 714, Total Reward: -100
# Episode: 715, Total Reward: -29
# Episode: 716, Total Reward: 7
# Episode: 717, Total Reward: -48
# Episode: 718, Total Reward: 7
# Episode: 719, Total Reward: -94
# Episode: 720, Total Reward: -14
# Episode: 721, Total Reward: -1
# Episode: 722, Total Reward: -4
# Episode: 723, Total Reward: -14
# Episode: 724, Total Reward: 12
# Episode: 725, Total Reward: 9
# Episode: 726, Total Reward: 15
# Episode: 727, Total Reward: 8
# Episode: 728, Total Reward: -8
# Episode: 729, Total Reward: -37
# Episode: 730, Total Reward: 3
# Episode: 731, Total Reward: -18
# Episode: 732, Total Reward: 10
# Episode: 733, Total Reward: 3
# Episode: 734, Total Reward: 8
# Episode: 735, Total Reward: 13
# Episode: 736, Total Reward: 14
# Episode: 737, Total Reward: 9
# Episode: 738, Total Reward: -149
# Episode: 739, Total Reward: -3
# Episode: 740, Total Reward: 12
# Episode: 741, Total Reward: 5
# Episode: 742, Total Reward: -24
# Episode: 743, Total Reward: -29
# Episode: 744, Total Reward: -12
# Episode: 745, Total Reward: -162
# Episode: 746, Total Reward: 0
# Episode: 747, Total Reward: 8
# Episode: 748, Total Reward: -51
# Episode: 749, Total Reward: -26
# Episode: 750, Total Reward: -35
# Episode: 751, Total Reward: -16
# Episode: 752, Total Reward: 7
# Episode: 753, Total Reward: -79
# Episode: 754, Total Reward: -12
# Episode: 755, Total Reward: 4
# Episode: 756, Total Reward: -39
# Episode: 757, Total Reward: -48
# Episode: 758, Total Reward: -24
# Episode: 759, Total Reward: -56
# Episode: 760, Total Reward: 1
# Episode: 761, Total Reward: -1
# Episode: 762, Total Reward: 9
# Episode: 763, Total Reward: 4
# Episode: 764, Total Reward: -3
# Episode: 765, Total Reward: -73
# Episode: 766, Total Reward: 8
# Episode: 767, Total Reward: -14
# Episode: 768, Total Reward: -66
# Episode: 769, Total Reward: -49
# Episode: 770, Total Reward: 2
# Episode: 771, Total Reward: -35
# Episode: 772, Total Reward: -45
# Episode: 773, Total Reward: 9
# Episode: 774, Total Reward: 8
# Episode: 775, Total Reward: -45
# Episode: 776, Total Reward: -50
# Episode: 777, Total Reward: 3
# Episode: 778, Total Reward: 12
# Episode: 779, Total Reward: -26
# Episode: 780, Total Reward: -7
# Episode: 781, Total Reward: -62
# Episode: 782, Total Reward: -6
# Episode: 783, Total Reward: -87
# Episode: 784, Total Reward: -151
# Episode: 785, Total Reward: 7
# Episode: 786, Total Reward: -5
# Episode: 787, Total Reward: -15
# Episode: 788, Total Reward: -26
# Episode: 789, Total Reward: 8
# Episode: 790, Total Reward: 2
# Episode: 791, Total Reward: -18
# Episode: 792, Total Reward: 13
# Episode: 793, Total Reward: -48
# Episode: 794, Total Reward: -19
# Episode: 795, Total Reward: 7
# Episode: 796, Total Reward: 10
# Episode: 797, Total Reward: -23
# Episode: 798, Total Reward: 10
# Episode: 799, Total Reward: 11
# Episode: 800, Total Reward: -3
# Episode: 801, Total Reward: -36
# Episode: 802, Total Reward: 9
# Episode: 803, Total Reward: 1
# Episode: 804, Total Reward: 8
# Episode: 805, Total Reward: -71
# Episode: 806, Total Reward: -11
# Episode: 807, Total Reward: -63
# Episode: 808, Total Reward: 10
# Episode: 809, Total Reward: 2
# Episode: 810, Total Reward: -33
# Episode: 811, Total Reward: -37
# Episode: 812, Total Reward: -32
# Episode: 813, Total Reward: 8
# Episode: 814, Total Reward: -79
# Episode: 815, Total Reward: -34
# Episode: 816, Total Reward: 3
# Episode: 817, Total Reward: 1
# Episode: 818, Total Reward: 4
# Episode: 819, Total Reward: 6
# Episode: 820, Total Reward: 13
# Episode: 821, Total Reward: 8
# Episode: 822, Total Reward: 8
# Episode: 823, Total Reward: 12
# Episode: 824, Total Reward: 0
# Episode: 825, Total Reward: -21
# Episode: 826, Total Reward: -9
# Episode: 827, Total Reward: 1
# Episode: 828, Total Reward: -11
# Episode: 829, Total Reward: -28
# Episode: 830, Total Reward: 13
# Episode: 831, Total Reward: 0
# Episode: 832, Total Reward: -10
# Episode: 833, Total Reward: -14
# Episode: 834, Total Reward: -7
# Episode: 835, Total Reward: -58
# Episode: 836, Total Reward: 12
# Episode: 837, Total Reward: -10
# Episode: 838, Total Reward: -15
# Episode: 839, Total Reward: -23
# Episode: 840, Total Reward: -18
# Episode: 841, Total Reward: 0
# Episode: 842, Total Reward: -30
# Episode: 843, Total Reward: 7
# Episode: 844, Total Reward: -68
# Episode: 845, Total Reward: 12
# Episode: 846, Total Reward: 12
# Episode: 847, Total Reward: -39
# Episode: 848, Total Reward: -156
# Episode: 849, Total Reward: -38
# Episode: 850, Total Reward: 9
# Episode: 851, Total Reward: 13
# Episode: 852, Total Reward: -2
# Episode: 853, Total Reward: -8
# Episode: 854, Total Reward: -37
# Episode: 855, Total Reward: -24
# Episode: 856, Total Reward: -8
# Episode: 857, Total Reward: -3
# Episode: 858, Total Reward: -124
# Episode: 859, Total Reward: 2
# Episode: 860, Total Reward: -1
# Episode: 861, Total Reward: 11
# Episode: 862, Total Reward: -16
# Episode: 863, Total Reward: 5
# Episode: 864, Total Reward: -25
# Episode: 865, Total Reward: 4
# Episode: 866, Total Reward: 7
# Episode: 867, Total Reward: 10
# Episode: 868, Total Reward: 11
# Episode: 869, Total Reward: -10
# Episode: 870, Total Reward: -3
# Episode: 871, Total Reward: -1
# Episode: 872, Total Reward: 10
# Episode: 873, Total Reward: -13
# Episode: 874, Total Reward: -59
# Episode: 875, Total Reward: 1
# Episode: 876, Total Reward: -12
# Episode: 877, Total Reward: -6
# Episode: 878, Total Reward: 12
# Episode: 879, Total Reward: -4
# Episode: 880, Total Reward: -6
# Episode: 881, Total Reward: -13
# Episode: 882, Total Reward: -7
# Episode: 883, Total Reward: -29
# Episode: 884, Total Reward: 9
# Episode: 885, Total Reward: 0
# Episode: 886, Total Reward: -18
# Episode: 887, Total Reward: 12
# Episode: 888, Total Reward: 8
# Episode: 889, Total Reward: -4
# Episode: 890, Total Reward: 5
# Episode: 891, Total Reward: 0
# Episode: 892, Total Reward: -13
# Episode: 893, Total Reward: 4
# Episode: 894, Total Reward: 13
# Episode: 895, Total Reward: -52
# Episode: 896, Total Reward: 8
# Episode: 897, Total Reward: 5
# Episode: 898, Total Reward: -102
# Episode: 899, Total Reward: 5
# Episode: 900, Total Reward: 3
# Episode: 901, Total Reward: 14
# Episode: 902, Total Reward: 10
# Episode: 903, Total Reward: 6
# Episode: 904, Total Reward: 8
# Episode: 905, Total Reward: 0
# Episode: 906, Total Reward: 10
# Episode: 907, Total Reward: -18
# Episode: 908, Total Reward: -6
# Episode: 909, Total Reward: 12
# Episode: 910, Total Reward: -3
# Episode: 911, Total Reward: 6
# Episode: 912, Total Reward: 11
# Episode: 913, Total Reward: -4
# Episode: 914, Total Reward: 12
# Episode: 915, Total Reward: 7
# Episode: 916, Total Reward: -10
# Episode: 917, Total Reward: 10
# Episode: 918, Total Reward: -23
# Episode: 919, Total Reward: 2
# Episode: 920, Total Reward: 9
# Episode: 921, Total Reward: 15
# Episode: 922, Total Reward: -10
# Episode: 923, Total Reward: -50
# Episode: 924, Total Reward: 3
# Episode: 925, Total Reward: -32
# Episode: 926, Total Reward: 4
# Episode: 927, Total Reward: -29
# Episode: 928, Total Reward: 8
# Episode: 929, Total Reward: 0
# Episode: 930, Total Reward: -6
# Episode: 931, Total Reward: -21
# Episode: 932, Total Reward: -44
# Episode: 933, Total Reward: 7
# Episode: 934, Total Reward: -83
# Episode: 935, Total Reward: -4
# Episode: 936, Total Reward: 10
# Episode: 937, Total Reward: -66
# Episode: 938, Total Reward: -7
# Episode: 939, Total Reward: -10
# Episode: 940, Total Reward: 12
# Episode: 941, Total Reward: -4
# Episode: 942, Total Reward: 12
# Episode: 943, Total Reward: 7
# Episode: 944, Total Reward: -27
# Episode: 945, Total Reward: 8
# Episode: 946, Total Reward: 13
# Episode: 947, Total Reward: 5
# Episode: 948, Total Reward: -9
# Episode: 949, Total Reward: 10
# Episode: 950, Total Reward: -2
# Episode: 951, Total Reward: 7
# Episode: 952, Total Reward: -12
# Episode: 953, Total Reward: 7
# Episode: 954, Total Reward: 7
# Episode: 955, Total Reward: -3
# Episode: 956, Total Reward: 8
# Episode: 957, Total Reward: -2
# Episode: 958, Total Reward: -40
# Episode: 959, Total Reward: 8
# Episode: 960, Total Reward: -14
# Episode: 961, Total Reward: -1
# Episode: 962, Total Reward: -28
# Episode: 963, Total Reward: 8
# Episode: 964, Total Reward: -19
# Episode: 965, Total Reward: -7
# Episode: 966, Total Reward: -17
# Episode: 967, Total Reward: -11
# Episode: 968, Total Reward: -10
# Episode: 969, Total Reward: -57
# Episode: 970, Total Reward: 2
# Episode: 971, Total Reward: -20
# Episode: 972, Total Reward: 10
# Episode: 973, Total Reward: 3
# Episode: 974, Total Reward: 10
# Episode: 975, Total Reward: 11
# Episode: 976, Total Reward: 11
# Episode: 977, Total Reward: -15
# Episode: 978, Total Reward: 10
# Episode: 979, Total Reward: 11
# Episode: 980, Total Reward: -26
# Episode: 981, Total Reward: 11
# Episode: 982, Total Reward: 10
# Episode: 983, Total Reward: -20
# Episode: 984, Total Reward: -5
# Episode: 985, Total Reward: 14
# Episode: 986, Total Reward: 1
# Episode: 987, Total Reward: 9
# Episode: 988, Total Reward: -30
# Episode: 989, Total Reward: 12
# Episode: 990, Total Reward: -1
# Episode: 991, Total Reward: 12
# Episode: 992, Total Reward: 9
# Episode: 993, Total Reward: 5
# Episode: 994, Total Reward: -20
# Episode: 995, Total Reward: 9
# Episode: 996, Total Reward: 8
# Episode: 997, Total Reward: -5
# Episode: 998, Total Reward: 5
# Episode: 999, Total Reward: 2
# Episode: 1000, Total Reward: 7
# Episode: 1001, Total Reward: 12
# Episode: 1002, Total Reward: 1
# Episode: 1003, Total Reward: -29
# Episode: 1004, Total Reward: -7
# Episode: 1005, Total Reward: 4
# Episode: 1006, Total Reward: -2
# Episode: 1007, Total Reward: 7
# Episode: 1008, Total Reward: -102
# Episode: 1009, Total Reward: 13
# Episode: 1010, Total Reward: 1
# Episode: 1011, Total Reward: 10
# Episode: 1012, Total Reward: -8
# Episode: 1013, Total Reward: -12
# Episode: 1014, Total Reward: 0
# Episode: 1015, Total Reward: 9
# Episode: 1016, Total Reward: -47
# Episode: 1017, Total Reward: 10
# Episode: 1018, Total Reward: 1
# Episode: 1019, Total Reward: -81
# Episode: 1020, Total Reward: 11
# Episode: 1021, Total Reward: 12
# Episode: 1022, Total Reward: 9
# Episode: 1023, Total Reward: 8
# Episode: 1024, Total Reward: 11
# Episode: 1025, Total Reward: 10
# Episode: 1026, Total Reward: 8
# Episode: 1027, Total Reward: 12
# Episode: 1028, Total Reward: 8
# Episode: 1029, Total Reward: 9
# Episode: 1030, Total Reward: -100
# Episode: 1031, Total Reward: -4
# Episode: 1032, Total Reward: 13
# Episode: 1033, Total Reward: -9
# Episode: 1034, Total Reward: 13
# Episode: 1035, Total Reward: 10
# Episode: 1036, Total Reward: 10
# Episode: 1037, Total Reward: -27
# Episode: 1038, Total Reward: -52
# Episode: 1039, Total Reward: 6
# Episode: 1040, Total Reward: -82
# Episode: 1041, Total Reward: 13
# Episode: 1042, Total Reward: 13
# Episode: 1043, Total Reward: 8
# Episode: 1044, Total Reward: 10
# Episode: 1045, Total Reward: 8
# Episode: 1046, Total Reward: -10
# Episode: 1047, Total Reward: 0
# Episode: 1048, Total Reward: 5
# Episode: 1049, Total Reward: 9
# Episode: 1050, Total Reward: 8
# Episode: 1051, Total Reward: -10
# Episode: 1052, Total Reward: -4
# Episode: 1053, Total Reward: 6
# Episode: 1054, Total Reward: 7
# Episode: 1055, Total Reward: -8
# Episode: 1056, Total Reward: 10
# Episode: 1057, Total Reward: 4
# Episode: 1058, Total Reward: -3
# Episode: 1059, Total Reward: 12
# Episode: 1060, Total Reward: 6
# Episode: 1061, Total Reward: 12
# Episode: 1062, Total Reward: -87
# Episode: 1063, Total Reward: 9
# Episode: 1064, Total Reward: -12
# Episode: 1065, Total Reward: -4
# Episode: 1066, Total Reward: 11
# Episode: 1067, Total Reward: 14
# Episode: 1068, Total Reward: -7
# Episode: 1069, Total Reward: 4
# Episode: 1070, Total Reward: 3
# Episode: 1071, Total Reward: 2
# Episode: 1072, Total Reward: 8
# Episode: 1073, Total Reward: 10
# Episode: 1074, Total Reward: 1
# Episode: 1075, Total Reward: 12
# Episode: 1076, Total Reward: -67
# Episode: 1077, Total Reward: 13
# Episode: 1078, Total Reward: 10
# Episode: 1079, Total Reward: 9
# Episode: 1080, Total Reward: 0
# Episode: 1081, Total Reward: 12
# Episode: 1082, Total Reward: 4
# Episode: 1083, Total Reward: -9
# Episode: 1084, Total Reward: 7
# Episode: 1085, Total Reward: 1
# Episode: 1086, Total Reward: -2
# Episode: 1087, Total Reward: 13
# Episode: 1088, Total Reward: 6
# Episode: 1089, Total Reward: -97
# Episode: 1090, Total Reward: 2
# Episode: 1091, Total Reward: -35
# Episode: 1092, Total Reward: 11
# Episode: 1093, Total Reward: -15
# Episode: 1094, Total Reward: 5
# Episode: 1095, Total Reward: 8
# Episode: 1096, Total Reward: 9
# Episode: 1097, Total Reward: 5
# Episode: 1098, Total Reward: 12
# Episode: 1099, Total Reward: 10
# Episode: 1100, Total Reward: 11
# Episode: 1101, Total Reward: -15
# Episode: 1102, Total Reward: 10
# Episode: 1103, Total Reward: 6
# Episode: 1104, Total Reward: 12
# Episode: 1105, Total Reward: 8
# Episode: 1106, Total Reward: 6
# Episode: 1107, Total Reward: 1
# Episode: 1108, Total Reward: -3
# Episode: 1109, Total Reward: 12
# Episode: 1110, Total Reward: -9
# Episode: 1111, Total Reward: 5
# Episode: 1112, Total Reward: -33
# Episode: 1113, Total Reward: 8
# Episode: 1114, Total Reward: 8
# Episode: 1115, Total Reward: -17
# Episode: 1116, Total Reward: -4
# Episode: 1117, Total Reward: 11
# Episode: 1118, Total Reward: 9
# Episode: 1119, Total Reward: 12
# Episode: 1120, Total Reward: 6
# Episode: 1121, Total Reward: 12
# Episode: 1122, Total Reward: -16
# Episode: 1123, Total Reward: 13
# Episode: 1124, Total Reward: -40
# Episode: 1125, Total Reward: 9
# Episode: 1126, Total Reward: 7
# Episode: 1127, Total Reward: 6
# Episode: 1128, Total Reward: 6
# Episode: 1129, Total Reward: 7
# Episode: 1130, Total Reward: 8
# Episode: 1131, Total Reward: 8
# Episode: 1132, Total Reward: 8
# Episode: 1133, Total Reward: 9
# Episode: 1134, Total Reward: -57
# Episode: 1135, Total Reward: 10
# Episode: 1136, Total Reward: 5
# Episode: 1137, Total Reward: -2
# Episode: 1138, Total Reward: 11
# Episode: 1139, Total Reward: 13
# Episode: 1140, Total Reward: 11
# Episode: 1141, Total Reward: -27
# Episode: 1142, Total Reward: 6
# Episode: 1143, Total Reward: 5
# Episode: 1144, Total Reward: 9
# Episode: 1145, Total Reward: 2
# Episode: 1146, Total Reward: 7
# Episode: 1147, Total Reward: 11
# Episode: 1148, Total Reward: 6
# Episode: 1149, Total Reward: 8
# Episode: 1150, Total Reward: 8
# Episode: 1151, Total Reward: 7
# Episode: 1152, Total Reward: -31
# Episode: 1153, Total Reward: 8
# Episode: 1154, Total Reward: -27
# Episode: 1155, Total Reward: 6
# Episode: 1156, Total Reward: 7
# Episode: 1157, Total Reward: -2
# Episode: 1158, Total Reward: 10
# Episode: 1159, Total Reward: 8
# Episode: 1160, Total Reward: 10
# Episode: 1161, Total Reward: -36
# Episode: 1162, Total Reward: 5
# Episode: 1163, Total Reward: 7
# Episode: 1164, Total Reward: -8
# Episode: 1165, Total Reward: 10
# Episode: 1166, Total Reward: 0
# Episode: 1167, Total Reward: 10
# Episode: 1168, Total Reward: -13
# Episode: 1169, Total Reward: 7
# Episode: 1170, Total Reward: 6
# Episode: 1171, Total Reward: 10
# Episode: 1172, Total Reward: -9
# Episode: 1173, Total Reward: 8
# Episode: 1174, Total Reward: 8
# Episode: 1175, Total Reward: 8
# Episode: 1176, Total Reward: -2
# Episode: 1177, Total Reward: 0
# Episode: 1178, Total Reward: 14
# Episode: 1179, Total Reward: 10
# Episode: 1180, Total Reward: 9
# Episode: 1181, Total Reward: 7
# Episode: 1182, Total Reward: 4
# Episode: 1183, Total Reward: 5
# Episode: 1184, Total Reward: 3
# Episode: 1185, Total Reward: 12
# Episode: 1186, Total Reward: -49
# Episode: 1187, Total Reward: 10
# Episode: 1188, Total Reward: 1
# Episode: 1189, Total Reward: 8
# Episode: 1190, Total Reward: 11
# Episode: 1191, Total Reward: -12
# Episode: 1192, Total Reward: -14
# Episode: 1193, Total Reward: -3
# Episode: 1194, Total Reward: 8
# Episode: 1195, Total Reward: -2
# Episode: 1196, Total Reward: 1
# Episode: 1197, Total Reward: 9
# Episode: 1198, Total Reward: -12
# Episode: 1199, Total Reward: 11
# Episode: 1200, Total Reward: 11
# Episode: 1201, Total Reward: 11
# Episode: 1202, Total Reward: 1
# Episode: 1203, Total Reward: 8
# Episode: 1204, Total Reward: 10
# Episode: 1205, Total Reward: 11
# Episode: 1206, Total Reward: 8
# Episode: 1207, Total Reward: 5
# Episode: 1208, Total Reward: 14
# Episode: 1209, Total Reward: -13
# Episode: 1210, Total Reward: 10
# Episode: 1211, Total Reward: -5
# Episode: 1212, Total Reward: 6
# Episode: 1213, Total Reward: 13
# Episode: 1214, Total Reward: 8
# Episode: 1215, Total Reward: -1
# Episode: 1216, Total Reward: -22
# Episode: 1217, Total Reward: 8
# Episode: 1218, Total Reward: 14
# Episode: 1219, Total Reward: 11
# Episode: 1220, Total Reward: 1
# Episode: 1221, Total Reward: 9
# Episode: 1222, Total Reward: 3
# Episode: 1223, Total Reward: 12
# Episode: 1224, Total Reward: 7
# Episode: 1225, Total Reward: 5
# Episode: 1226, Total Reward: 8
# Episode: 1227, Total Reward: -20
# Episode: 1228, Total Reward: 4
# Episode: 1229, Total Reward: -12
# Episode: 1230, Total Reward: 9
# Episode: 1231, Total Reward: 8
# Episode: 1232, Total Reward: 12
# Episode: 1233, Total Reward: 8
# Episode: 1234, Total Reward: 9
# Episode: 1235, Total Reward: 8
# Episode: 1236, Total Reward: 1
# Episode: 1237, Total Reward: 11
# Episode: 1238, Total Reward: 7
# Episode: 1239, Total Reward: 8
# Episode: 1240, Total Reward: 11
# Episode: 1241, Total Reward: -1
# Episode: 1242, Total Reward: 7
# Episode: 1243, Total Reward: 5
# Episode: 1244, Total Reward: 1
# Episode: 1245, Total Reward: 8
# Episode: 1246, Total Reward: -15
# Episode: 1247, Total Reward: 8
# Episode: 1248, Total Reward: 11
# Episode: 1249, Total Reward: -2
# Episode: 1250, Total Reward: 8
# Episode: 1251, Total Reward: 0
# Episode: 1252, Total Reward: 7
# Episode: 1253, Total Reward: -17
# Episode: 1254, Total Reward: -4
# Episode: 1255, Total Reward: 9
# Episode: 1256, Total Reward: 5
# Episode: 1257, Total Reward: 10
# Episode: 1258, Total Reward: -41
# Episode: 1259, Total Reward: 10
# Episode: 1260, Total Reward: 14
# Episode: 1261, Total Reward: 3
# Episode: 1262, Total Reward: 6
# Episode: 1263, Total Reward: 12
# Episode: 1264, Total Reward: 7
# Episode: 1265, Total Reward: 11
# Episode: 1266, Total Reward: 9
# Episode: 1267, Total Reward: 11
# Episode: 1268, Total Reward: 4
# Episode: 1269, Total Reward: 14
# Episode: 1270, Total Reward: 7
# Episode: 1271, Total Reward: -2
# Episode: 1272, Total Reward: 3
# Episode: 1273, Total Reward: 5
# Episode: 1274, Total Reward: -2
# Episode: 1275, Total Reward: 7
# Episode: 1276, Total Reward: 2
# Episode: 1277, Total Reward: 10
# Episode: 1278, Total Reward: 11
# Episode: 1279, Total Reward: 8
# Episode: 1280, Total Reward: 11
# Episode: 1281, Total Reward: 8
# Episode: 1282, Total Reward: -3
# Episode: 1283, Total Reward: 7
# Episode: 1284, Total Reward: -7
# Episode: 1285, Total Reward: 9
# Episode: 1286, Total Reward: 5
# Episode: 1287, Total Reward: 11
# Episode: 1288, Total Reward: 10
# Episode: 1289, Total Reward: 12
# Episode: 1290, Total Reward: 4
# Episode: 1291, Total Reward: -26
# Episode: 1292, Total Reward: 8
# Episode: 1293, Total Reward: 0
# Episode: 1294, Total Reward: 8
# Episode: 1295, Total Reward: -7
# Episode: 1296, Total Reward: -7
# Episode: 1297, Total Reward: 13
# Episode: 1298, Total Reward: 3
# Episode: 1299, Total Reward: 9
# Episode: 1300, Total Reward: -1
# Episode: 1301, Total Reward: 9
# Episode: 1302, Total Reward: 7
# Episode: 1303, Total Reward: 7
# Episode: 1304, Total Reward: 9
# Episode: 1305, Total Reward: 11
# Episode: 1306, Total Reward: 10
# Episode: 1307, Total Reward: 2
# Episode: 1308, Total Reward: 12
# Episode: 1309, Total Reward: 7
# Episode: 1310, Total Reward: 10
# Episode: 1311, Total Reward: 8
# Episode: 1312, Total Reward: -2
# Episode: 1313, Total Reward: -6
# Episode: 1314, Total Reward: 11
# Episode: 1315, Total Reward: -4
# Episode: 1316, Total Reward: 8
# Episode: 1317, Total Reward: 4
# Episode: 1318, Total Reward: 9
# Episode: 1319, Total Reward: 7
# Episode: 1320, Total Reward: 11
# Episode: 1321, Total Reward: 8
# Episode: 1322, Total Reward: 3
# Episode: 1323, Total Reward: 11
# Episode: 1324, Total Reward: 6
# Episode: 1325, Total Reward: 10
# Episode: 1326, Total Reward: 2
# Episode: 1327, Total Reward: 7
# Episode: 1328, Total Reward: 7
# Episode: 1329, Total Reward: 10
# Episode: 1330, Total Reward: 10
# Episode: 1331, Total Reward: 13
# Episode: 1332, Total Reward: 7
# Episode: 1333, Total Reward: 12
# Episode: 1334, Total Reward: -6
# Episode: 1335, Total Reward: -62
# Episode: 1336, Total Reward: 5
# Episode: 1337, Total Reward: 13
# Episode: 1338, Total Reward: -13
# Episode: 1339, Total Reward: -5
# Episode: 1340, Total Reward: 8
# Episode: 1341, Total Reward: 7
# Episode: 1342, Total Reward: 4
# Episode: 1343, Total Reward: 8
# Episode: 1344, Total Reward: 0
# Episode: 1345, Total Reward: 4
# Episode: 1346, Total Reward: 7
# Episode: 1347, Total Reward: 9
# Episode: 1348, Total Reward: -36
# Episode: 1349, Total Reward: 1
# Episode: 1350, Total Reward: 9
# Episode: 1351, Total Reward: -60
# Episode: 1352, Total Reward: 8
# Episode: 1353, Total Reward: 9
# Episode: 1354, Total Reward: -12
# Episode: 1355, Total Reward: 7
# Episode: 1356, Total Reward: -4
# Episode: 1357, Total Reward: -15
# Episode: 1358, Total Reward: -1
# Episode: 1359, Total Reward: 9
# Episode: 1360, Total Reward: 6
# Episode: 1361, Total Reward: -18
# Episode: 1362, Total Reward: 4
# Episode: 1363, Total Reward: 10
# Episode: 1364, Total Reward: 3
# Episode: 1365, Total Reward: 12
# Episode: 1366, Total Reward: -28
# Episode: 1367, Total Reward: 7
# Episode: 1368, Total Reward: 10
# Episode: 1369, Total Reward: 2
# Episode: 1370, Total Reward: 8
# Episode: 1371, Total Reward: 8
# Episode: 1372, Total Reward: 8
# Episode: 1373, Total Reward: -7
# Episode: 1374, Total Reward: 8
# Episode: 1375, Total Reward: 9
# Episode: 1376, Total Reward: 14
# Episode: 1377, Total Reward: 4
# Episode: 1378, Total Reward: 2
# Episode: 1379, Total Reward: 8
# Episode: 1380, Total Reward: 13
# Episode: 1381, Total Reward: 7
# Episode: 1382, Total Reward: 9
# Episode: 1383, Total Reward: 12
# Episode: 1384, Total Reward: 10
# Episode: 1385, Total Reward: 7
# Episode: 1386, Total Reward: 4
# Episode: 1387, Total Reward: 6
# Episode: 1388, Total Reward: 8
# Episode: 1389, Total Reward: 7
# Episode: 1390, Total Reward: 9
# Episode: 1391, Total Reward: -2
# Episode: 1392, Total Reward: 14
# Episode: 1393, Total Reward: 7
# Episode: 1394, Total Reward: 5
# Episode: 1395, Total Reward: 11
# Episode: 1396, Total Reward: 4
# Episode: 1397, Total Reward: 2
# Episode: 1398, Total Reward: 6
# Episode: 1399, Total Reward: 12
# Episode: 1400, Total Reward: 1
# Episode: 1401, Total Reward: 6
# Episode: 1402, Total Reward: 5
# Episode: 1403, Total Reward: 6
# Episode: 1404, Total Reward: 9
# Episode: 1405, Total Reward: 7
# Episode: 1406, Total Reward: 10
# Episode: 1407, Total Reward: 5
# Episode: 1408, Total Reward: -10
# Episode: 1409, Total Reward: 10
# Episode: 1410, Total Reward: 8
# Episode: 1411, Total Reward: 8
# Episode: 1412, Total Reward: 7
# Episode: 1413, Total Reward: -7
# Episode: 1414, Total Reward: 8
# Episode: 1415, Total Reward: 11
# Episode: 1416, Total Reward: 12
# Episode: 1417, Total Reward: 8
# Episode: 1418, Total Reward: 12
# Episode: 1419, Total Reward: -12
# Episode: 1420, Total Reward: -10
# Episode: 1421, Total Reward: 2
# Episode: 1422, Total Reward: 7
# Episode: 1423, Total Reward: 5
# Episode: 1424, Total Reward: 6
# Episode: 1425, Total Reward: 7
# Episode: 1426, Total Reward: 3
# Episode: 1427, Total Reward: 0
# Episode: 1428, Total Reward: 7
# Episode: 1429, Total Reward: 6
# Episode: 1430, Total Reward: 11
# Episode: 1431, Total Reward: 9
# Episode: 1432, Total Reward: 13
# Episode: 1433, Total Reward: 1
# Episode: 1434, Total Reward: -9
# Episode: 1435, Total Reward: 9
# Episode: 1436, Total Reward: -3
# Episode: 1437, Total Reward: 9
# Episode: 1438, Total Reward: 4
# Episode: 1439, Total Reward: 4
# Episode: 1440, Total Reward: 7
# Episode: 1441, Total Reward: 7
# Episode: 1442, Total Reward: 14
# Episode: 1443, Total Reward: 15
# Episode: 1444, Total Reward: 3
# Episode: 1445, Total Reward: 7
# Episode: 1446, Total Reward: -3
# Episode: 1447, Total Reward: 4
# Episode: 1448, Total Reward: 8
# Episode: 1449, Total Reward: 6
# Episode: 1450, Total Reward: 7
# Episode: 1451, Total Reward: 8
# Episode: 1452, Total Reward: 8
# Episode: 1453, Total Reward: 4
# Episode: 1454, Total Reward: -13
# Episode: 1455, Total Reward: 6
# Episode: 1456, Total Reward: 10
# Episode: 1457, Total Reward: 5
# Episode: 1458, Total Reward: 6
# Episode: 1459, Total Reward: 10
# Episode: 1460, Total Reward: -5
# Episode: 1461, Total Reward: 9
# Episode: 1462, Total Reward: 8
# Episode: 1463, Total Reward: 6
# Episode: 1464, Total Reward: 2
# Episode: 1465, Total Reward: 9
# Episode: 1466, Total Reward: 5
# Episode: 1467, Total Reward: 14
# Episode: 1468, Total Reward: 7
# Episode: 1469, Total Reward: -2
# Episode: 1470, Total Reward: 8
# Episode: 1471, Total Reward: 14
# Episode: 1472, Total Reward: -2
# Episode: 1473, Total Reward: 7
# Episode: 1474, Total Reward: 8
# Episode: 1475, Total Reward: 5
# Episode: 1476, Total Reward: 10
# Episode: 1477, Total Reward: 12
# Episode: 1478, Total Reward: 15
# Episode: 1479, Total Reward: 2
# Episode: 1480, Total Reward: 11
# Episode: 1481, Total Reward: 8
# Episode: 1482, Total Reward: 6
# Episode: 1483, Total Reward: 12
# Episode: 1484, Total Reward: -1
# Episode: 1485, Total Reward: 8
# Episode: 1486, Total Reward: 0
# Episode: 1487, Total Reward: 4
# Episode: 1488, Total Reward: -14
# Episode: 1489, Total Reward: 10
# Episode: 1490, Total Reward: 7
# Episode: 1491, Total Reward: 5
# Episode: 1492, Total Reward: 7
# Episode: 1493, Total Reward: 6
# Episode: 1494, Total Reward: 12
# Episode: 1495, Total Reward: 7
# Episode: 1496, Total Reward: 7
# Episode: 1497, Total Reward: 9
# Episode: 1498, Total Reward: 11
# Episode: 1499, Total Reward: 12
# Episode: 1500, Total Reward: 6
# Episode: 1501, Total Reward: 9
# Episode: 1502, Total Reward: 7
# Episode: 1503, Total Reward: 8
# Episode: 1504, Total Reward: 8
# Episode: 1505, Total Reward: 4
# Episode: 1506, Total Reward: 9
# Episode: 1507, Total Reward: 7
# Episode: 1508, Total Reward: -3
# Episode: 1509, Total Reward: 12
# Episode: 1510, Total Reward: 3
# Episode: 1511, Total Reward: 11
# ...
# Episode: 4491, Total Reward: 9
# Episode: 4492, Total Reward: 12
# Episode: 4493, Total Reward: 7
# Episode: 4494, Total Reward: 7
# Episode: 4495, Total Reward: 12
# Episode: 4496, Total Reward: 4
# Episode: 4497, Total Reward: 4
# Episode: 4498, Total Reward: 5
# Episode: 4499, Total Reward: 4
# Episode: 4500, Total Reward: 6
# Episode: 4501, Total Reward: 6
# Episode: 4502, Total Reward: 6
# Episode: 4503, Total Reward: 8
# Episode: 4504, Total Reward: 11
# Episode: 4505, Total Reward: 7
# Episode: 4506, Total Reward: 10
# Episode: 4507, Total Reward: 10
# Episode: 4508, Total Reward: 8
# Episode: 4509, Total Reward: 11
# Episode: 4510, Total Reward: 11
# Episode: 4511, Total Reward: 7
# Episode: 4512, Total Reward: 4
# Episode: 4513, Total Reward: 11
# Episode: 4514, Total Reward: 8
# Episode: 4515, Total Reward: 4
# Episode: 4516, Total Reward: 5
# Episode: 4517, Total Reward: 7
# Episode: 4518, Total Reward: 4
# Episode: 4519, Total Reward: 3
# Episode: 4520, Total Reward: 7
# Episode: 4521, Total Reward: 6
# Episode: 4522, Total Reward: 8
# Episode: 4523, Total Reward: 6
# Episode: 4524, Total Reward: 13
# Episode: 4525, Total Reward: 5
# Episode: 4526, Total Reward: 7
# Episode: 4527, Total Reward: 9
# Episode: 4528, Total Reward: 6
# Episode: 4529, Total Reward: 8
# Episode: 4530, Total Reward: 7
# Episode: 4531, Total Reward: 9
# Episode: 4532, Total Reward: 8
# Episode: 4533, Total Reward: 5
# Episode: 4534, Total Reward: 13
# Episode: 4535, Total Reward: 4
# Episode: 4536, Total Reward: 7
# Episode: 4537, Total Reward: 9
# Episode: 4538, Total Reward: 4
# Episode: 4539, Total Reward: 9
# Episode: 4540, Total Reward: 3
# Episode: 4541, Total Reward: 7
# Episode: 4542, Total Reward: 9
# Episode: 4543, Total Reward: 10
# Episode: 4544, Total Reward: 5
# Episode: 4545, Total Reward: 13
# Episode: 4546, Total Reward: 9
# Episode: 4547, Total Reward: 7
# Episode: 4548, Total Reward: 7
# Episode: 4549, Total Reward: 6
# Episode: 4550, Total Reward: 4
# Episode: 4551, Total Reward: 3
# Episode: 4552, Total Reward: 10
# Episode: 4553, Total Reward: 6
# Episode: 4554, Total Reward: 7
# Episode: 4555, Total Reward: 11
# Episode: 4556, Total Reward: 10
# Episode: 4557, Total Reward: 6
# Episode: 4558, Total Reward: 7
# Episode: 4559, Total Reward: 2
# Episode: 4560, Total Reward: 4
# Episode: 4561, Total Reward: 3
# Episode: 4562, Total Reward: 4
# Episode: 4563, Total Reward: 6
# Episode: 4564, Total Reward: 7
# Episode: 4565, Total Reward: 10
# Episode: 4566, Total Reward: -3
# Episode: 4567, Total Reward: 11
# Episode: 4568, Total Reward: 10
# Episode: 4569, Total Reward: 7
# Episode: 4570, Total Reward: 11
# Episode: 4571, Total Reward: 6
# Episode: 4572, Total Reward: 5
# Episode: 4573, Total Reward: 10
# Episode: 4574, Total Reward: 7
# Episode: 4575, Total Reward: 5
# Episode: 4576, Total Reward: 7
# Episode: 4577, Total Reward: 4
# Episode: 4578, Total Reward: 5
# Episode: 4579, Total Reward: 6
# Episode: 4580, Total Reward: 5
# Episode: 4581, Total Reward: 7
# Episode: 4582, Total Reward: 9
# Episode: 4583, Total Reward: 14
# Episode: 4584, Total Reward: 6
# Episode: 4585, Total Reward: 15
# Episode: 4586, Total Reward: 9
# Episode: 4587, Total Reward: 12
# Episode: 4588, Total Reward: 6
# Episode: 4589, Total Reward: 10
# Episode: 4590, Total Reward: 9
# Episode: 4591, Total Reward: 8
# Episode: 4592, Total Reward: 9
# Episode: 4593, Total Reward: 6
# Episode: 4594, Total Reward: 6
# Episode: 4595, Total Reward: 8
# Episode: 4596, Total Reward: 6
# Episode: 4597, Total Reward: 10
# Episode: 4598, Total Reward: 7
# Episode: 4599, Total Reward: 9
# Episode: 4600, Total Reward: 10
# Episode: 4601, Total Reward: 7
# Episode: 4602, Total Reward: 9
# Episode: 4603, Total Reward: 4
# Episode: 4604, Total Reward: 10
# Episode: 4605, Total Reward: 8
# Episode: 4606, Total Reward: 9
# Episode: 4607, Total Reward: 10
# Episode: 4608, Total Reward: 7
# Episode: 4609, Total Reward: 3
# Episode: 4610, Total Reward: 10
# Episode: 4611, Total Reward: 7
# Episode: 4612, Total Reward: 10
# Episode: 4613, Total Reward: 9
# Episode: 4614, Total Reward: 9
# Episode: 4615, Total Reward: 7
# Episode: 4616, Total Reward: 7
# Episode: 4617, Total Reward: 9
# Episode: 4618, Total Reward: 5
# Episode: 4619, Total Reward: 8
# Episode: 4620, Total Reward: 14
# Episode: 4621, Total Reward: 10
# Episode: 4622, Total Reward: 4
# Episode: 4623, Total Reward: 7
# Episode: 4624, Total Reward: 10
# Episode: 4625, Total Reward: 11
# Episode: 4626, Total Reward: -1
# Episode: 4627, Total Reward: 12
# Episode: 4628, Total Reward: 8
# Episode: 4629, Total Reward: 12
# Episode: 4630, Total Reward: 14
# Episode: 4631, Total Reward: 7
# Episode: 4632, Total Reward: 8
# Episode: 4633, Total Reward: 10
# Episode: 4634, Total Reward: 12
# Episode: 4635, Total Reward: 5
# Episode: 4636, Total Reward: 10
# Episode: 4637, Total Reward: 9
# Episode: 4638, Total Reward: 14
# Episode: 4639, Total Reward: 9
# Episode: 4640, Total Reward: 6
# Episode: 4641, Total Reward: 11
# Episode: 4642, Total Reward: 10
# Episode: 4643, Total Reward: 7
# Episode: 4644, Total Reward: 4
# Episode: 4645, Total Reward: 6
# Episode: 4646, Total Reward: 6
# Episode: 4647, Total Reward: -3
# Episode: 4648, Total Reward: 9
# Episode: 4649, Total Reward: -4
# Episode: 4650, Total Reward: 9
# Episode: 4651, Total Reward: 9
# Episode: 4652, Total Reward: 9
# Episode: 4653, Total Reward: 6
# Episode: 4654, Total Reward: 10
# Episode: 4655, Total Reward: 9
# Episode: 4656, Total Reward: 11
# Episode: 4657, Total Reward: 7
# Episode: 4658, Total Reward: 10
# Episode: 4659, Total Reward: 10
# Episode: 4660, Total Reward: 7
# Episode: 4661, Total Reward: 8
# Episode: 4662, Total Reward: 3
# Episode: 4663, Total Reward: 10
# Episode: 4664, Total Reward: 7
# Episode: 4665, Total Reward: 8
# Episode: 4666, Total Reward: 8
# Episode: 4667, Total Reward: 10
# Episode: 4668, Total Reward: 7
# Episode: 4669, Total Reward: 6
# Episode: 4670, Total Reward: 13
# Episode: 4671, Total Reward: 7
# Episode: 4672, Total Reward: 6
# Episode: 4673, Total Reward: 9
# Episode: 4674, Total Reward: 2
# Episode: 4675, Total Reward: 11
# Episode: 4676, Total Reward: 7
# Episode: 4677, Total Reward: 7
# Episode: 4678, Total Reward: 11
# Episode: 4679, Total Reward: 6
# Episode: 4680, Total Reward: 7
# Episode: 4681, Total Reward: 9
# Episode: 4682, Total Reward: 6
# Episode: 4683, Total Reward: 8
# Episode: 4684, Total Reward: 4
# Episode: 4685, Total Reward: 9
# Episode: 4686, Total Reward: 4
# Episode: 4687, Total Reward: 3
# Episode: 4688, Total Reward: 7
# Episode: 4689, Total Reward: 0
# Episode: 4690, Total Reward: 5
# Episode: 4691, Total Reward: 7
# Episode: 4692, Total Reward: 8
# Episode: 4693, Total Reward: 6
# Episode: 4694, Total Reward: 9
# Episode: 4695, Total Reward: 7
# Episode: 4696, Total Reward: 7
# Episode: 4697, Total Reward: 14
# Episode: 4698, Total Reward: 7
# Episode: 4699, Total Reward: 7
# Episode: 4700, Total Reward: 7
# Episode: 4701, Total Reward: 9
# Episode: 4702, Total Reward: -10
# Episode: 4703, Total Reward: 11
# Episode: 4704, Total Reward: 7
# Episode: 4705, Total Reward: 10
# Episode: 4706, Total Reward: 11
# Episode: 4707, Total Reward: 6
# Episode: 4708, Total Reward: 5
# Episode: 4709, Total Reward: 12
# Episode: 4710, Total Reward: 5
# Episode: 4711, Total Reward: 10
# Episode: 4712, Total Reward: 5
# Episode: 4713, Total Reward: 10
# Episode: 4714, Total Reward: 12
# Episode: 4715, Total Reward: 4
# Episode: 4716, Total Reward: 7
# Episode: 4717, Total Reward: 8
# Episode: 4718, Total Reward: 9
# Episode: 4719, Total Reward: 4
# Episode: 4720, Total Reward: 8
# Episode: 4721, Total Reward: 7
# Episode: 4722, Total Reward: 10
# Episode: 4723, Total Reward: 12
# Episode: 4724, Total Reward: 14
# Episode: 4725, Total Reward: 5
# Episode: 4726, Total Reward: 5
# Episode: 4727, Total Reward: 6
# Episode: 4728, Total Reward: 7
# Episode: 4729, Total Reward: 11
# Episode: 4730, Total Reward: 7
# Episode: 4731, Total Reward: -1
# Episode: 4732, Total Reward: 10
# Episode: 4733, Total Reward: 5
# Episode: 4734, Total Reward: 12
# Episode: 4735, Total Reward: 11
# Episode: 4736, Total Reward: 3
# Episode: 4737, Total Reward: 11
# Episode: 4738, Total Reward: 5
# Episode: 4739, Total Reward: 10
# Episode: 4740, Total Reward: 12
# Episode: 4741, Total Reward: 9
# Episode: 4742, Total Reward: 7
# Episode: 4743, Total Reward: 6
# Episode: 4744, Total Reward: 9
# Episode: 4745, Total Reward: 7
# Episode: 4746, Total Reward: 6
# Episode: 4747, Total Reward: 9
# Episode: 4748, Total Reward: 6
# Episode: 4749, Total Reward: 5
# Episode: 4750, Total Reward: 8
# Episode: 4751, Total Reward: 8
# Episode: 4752, Total Reward: -4
# Episode: 4753, Total Reward: 13
# Episode: 4754, Total Reward: 5
# Episode: 4755, Total Reward: 10
# Episode: 4756, Total Reward: 6
# Episode: 4757, Total Reward: 8
# Episode: 4758, Total Reward: 6
# Episode: 4759, Total Reward: 10
# Episode: 4760, Total Reward: 6
# Episode: 4761, Total Reward: 10
# Episode: 4762, Total Reward: 5
# Episode: 4763, Total Reward: 6
# Episode: 4764, Total Reward: 5
# Episode: 4765, Total Reward: 8
# Episode: 4766, Total Reward: 6
# Episode: 4767, Total Reward: 5
# Episode: 4768, Total Reward: 10
# Episode: 4769, Total Reward: 9
# Episode: 4770, Total Reward: 15
# Episode: 4771, Total Reward: 7
# Episode: 4772, Total Reward: 5
# Episode: 4773, Total Reward: 8
# Episode: 4774, Total Reward: 4
# Episode: 4775, Total Reward: 9
# Episode: 4776, Total Reward: 9
# Episode: 4777, Total Reward: 6
# Episode: 4778, Total Reward: 7
# Episode: 4779, Total Reward: 7
# Episode: 4780, Total Reward: 10
# Episode: 4781, Total Reward: -2
# Episode: 4782, Total Reward: 10
# Episode: 4783, Total Reward: 12
# Episode: 4784, Total Reward: 10
# Episode: 4785, Total Reward: 6
# Episode: 4786, Total Reward: 5
# Episode: 4787, Total Reward: 8
# Episode: 4788, Total Reward: 4
# Episode: 4789, Total Reward: 8
# Episode: 4790, Total Reward: 10
# Episode: 4791, Total Reward: 11
# Episode: 4792, Total Reward: 7
# Episode: 4793, Total Reward: 8
# Episode: 4794, Total Reward: 6
# Episode: 4795, Total Reward: -1
# Episode: 4796, Total Reward: 12
# Episode: 4797, Total Reward: 13
# Episode: 4798, Total Reward: 10
# Episode: 4799, Total Reward: 7
# Episode: 4800, Total Reward: 9
# Episode: 4801, Total Reward: 9
# Episode: 4802, Total Reward: -1
# Episode: 4803, Total Reward: 4
# Episode: 4804, Total Reward: 10
# Episode: 4805, Total Reward: 6
# Episode: 4806, Total Reward: -2
# Episode: 4807, Total Reward: 7
# Episode: 4808, Total Reward: 10
# Episode: 4809, Total Reward: 7
# Episode: 4810, Total Reward: 6
# Episode: 4811, Total Reward: 11
# Episode: 4812, Total Reward: 10
# Episode: 4813, Total Reward: 12
# Episode: 4814, Total Reward: 15
# Episode: 4815, Total Reward: 6
# Episode: 4816, Total Reward: 8
# Episode: 4817, Total Reward: 7
# Episode: 4818, Total Reward: 4
# Episode: 4819, Total Reward: 9
# Episode: 4820, Total Reward: 8
# Episode: 4821, Total Reward: 3
# Episode: 4822, Total Reward: 4
# Episode: 4823, Total Reward: 11
# Episode: 4824, Total Reward: 8
# Episode: 4825, Total Reward: 10
# Episode: 4826, Total Reward: 7
# Episode: 4827, Total Reward: 11
# Episode: 4828, Total Reward: 7
# Episode: 4829, Total Reward: 8
# Episode: 4830, Total Reward: 10
# Episode: 4831, Total Reward: 8
# Episode: 4832, Total Reward: 10
# Episode: 4833, Total Reward: 7
# Episode: 4834, Total Reward: 8
# Episode: 4835, Total Reward: 8
# Episode: 4836, Total Reward: -5
# Episode: 4837, Total Reward: 9
# Episode: 4838, Total Reward: 6
# Episode: 4839, Total Reward: 11
# Episode: 4840, Total Reward: 15
# Episode: 4841, Total Reward: 7
# Episode: 4842, Total Reward: -1
# Episode: 4843, Total Reward: 11
# Episode: 4844, Total Reward: 8
# Episode: 4845, Total Reward: 6
# Episode: 4846, Total Reward: 13
# Episode: 4847, Total Reward: 0
# Episode: 4848, Total Reward: 8
# Episode: 4849, Total Reward: 10
# Episode: 4850, Total Reward: 6
# Episode: 4851, Total Reward: 7
# Episode: 4852, Total Reward: 11
# Episode: 4853, Total Reward: 9
# Episode: 4854, Total Reward: 7
# Episode: 4855, Total Reward: 9
# Episode: 4856, Total Reward: 9
# Episode: 4857, Total Reward: 7
# Episode: 4858, Total Reward: 10
# Episode: 4859, Total Reward: 7
# Episode: 4860, Total Reward: 10
# Episode: 4861, Total Reward: 10
# Episode: 4862, Total Reward: 9
# Episode: 4863, Total Reward: 7
# Episode: 4864, Total Reward: 4
# Episode: 4865, Total Reward: 12
# Episode: 4866, Total Reward: 9
# Episode: 4867, Total Reward: -6
# Episode: 4868, Total Reward: 10
# Episode: 4869, Total Reward: 14
# Episode: 4870, Total Reward: 9
# Episode: 4871, Total Reward: 9
# Episode: 4872, Total Reward: 8
# Episode: 4873, Total Reward: 5
# Episode: 4874, Total Reward: 8
# Episode: 4875, Total Reward: 10
# Episode: 4876, Total Reward: 6
# Episode: 4877, Total Reward: 8
# Episode: 4878, Total Reward: 9
# Episode: 4879, Total Reward: 4
# Episode: 4880, Total Reward: 5
# Episode: 4881, Total Reward: 5
# Episode: 4882, Total Reward: 9
# Episode: 4883, Total Reward: 11
# Episode: 4884, Total Reward: 3
# Episode: 4885, Total Reward: 5
# Episode: 4886, Total Reward: 9
# Episode: 4887, Total Reward: 4
# Episode: 4888, Total Reward: 10
# Episode: 4889, Total Reward: 3
# Episode: 4890, Total Reward: 8
# Episode: 4891, Total Reward: 5
# Episode: 4892, Total Reward: 7
# Episode: 4893, Total Reward: 5
# Episode: 4894, Total Reward: 8
# Episode: 4895, Total Reward: 5
# Episode: 4896, Total Reward: 6
# Episode: 4897, Total Reward: 14
# Episode: 4898, Total Reward: 4
# Episode: 4899, Total Reward: 13
# Episode: 4900, Total Reward: 12
# Episode: 4901, Total Reward: 10
# Episode: 4902, Total Reward: 5
# Episode: 4903, Total Reward: 4
# Episode: 4904, Total Reward: 10
# Episode: 4905, Total Reward: 7
# Episode: 4906, Total Reward: 11
# Episode: 4907, Total Reward: 11
# Episode: 4908, Total Reward: 10
# Episode: 4909, Total Reward: 11
# Episode: 4910, Total Reward: 6
# Episode: 4911, Total Reward: 7
# Episode: 4912, Total Reward: 11
# Episode: 4913, Total Reward: 6
# Episode: 4914, Total Reward: 10
# Episode: 4915, Total Reward: 8
# Episode: 4916, Total Reward: 11
# Episode: 4917, Total Reward: 9
# Episode: 4918, Total Reward: 5
# Episode: 4919, Total Reward: 6
# Episode: 4920, Total Reward: 7
# Episode: 4921, Total Reward: 3
# Episode: 4922, Total Reward: 4
# Episode: 4923, Total Reward: 5
# Episode: 4924, Total Reward: 9
# Episode: 4925, Total Reward: 9
# Episode: 4926, Total Reward: 4
# Episode: 4927, Total Reward: 8
# Episode: 4928, Total Reward: 8
# Episode: 4929, Total Reward: 5
# Episode: 4930, Total Reward: 10
# Episode: 4931, Total Reward: 7
# Episode: 4932, Total Reward: 8
# Episode: 4933, Total Reward: 6
# Episode: 4934, Total Reward: 12
# Episode: 4935, Total Reward: 11
# Episode: 4936, Total Reward: 12
# Episode: 4937, Total Reward: 0
# Episode: 4938, Total Reward: 7
# Episode: 4939, Total Reward: 8
# Episode: 4940, Total Reward: 8
# Episode: 4941, Total Reward: 7
# Episode: 4942, Total Reward: 7
# Episode: 4943, Total Reward: 4
# Episode: 4944, Total Reward: 10
# Episode: 4945, Total Reward: 7
# Episode: 4946, Total Reward: 3
# Episode: 4947, Total Reward: -2
# Episode: 4948, Total Reward: 6
# Episode: 4949, Total Reward: 10
# Episode: 4950, Total Reward: 12
# Episode: 4951, Total Reward: 5
# Episode: 4952, Total Reward: -2
# Episode: 4953, Total Reward: 9
# Episode: 4954, Total Reward: 9
# Episode: 4955, Total Reward: 14
# Episode: 4956, Total Reward: 2
# Episode: 4957, Total Reward: 5
# Episode: 4958, Total Reward: 11
# Episode: 4959, Total Reward: 8
# Episode: 4960, Total Reward: -1
# Episode: 4961, Total Reward: 7
# Episode: 4962, Total Reward: 4
# Episode: 4963, Total Reward: 12
# Episode: 4964, Total Reward: 10
# Episode: 4965, Total Reward: 5
# Episode: 4966, Total Reward: 8
# Episode: 4967, Total Reward: 14
# Episode: 4968, Total Reward: 3
# Episode: 4969, Total Reward: 12
# Episode: 4970, Total Reward: 7
# Episode: 4971, Total Reward: 8
# Episode: 4972, Total Reward: 10
# Episode: 4973, Total Reward: 7
# Episode: 4974, Total Reward: 12
# Episode: 4975, Total Reward: 11
# Episode: 4976, Total Reward: 3
# Episode: 4977, Total Reward: 10
# Episode: 4978, Total Reward: 10
# Episode: 4979, Total Reward: 7
# Episode: 4980, Total Reward: 7
# Episode: 4981, Total Reward: 7
# Episode: 4982, Total Reward: 4
# Episode: 4983, Total Reward: 3
# Episode: 4984, Total Reward: 8
# Episode: 4985, Total Reward: 5
# Episode: 4986, Total Reward: 10
# Episode: 4987, Total Reward: 7
# Episode: 4988, Total Reward: -3
# Episode: 4989, Total Reward: 9
# Episode: 4990, Total Reward: 10
# Episode: 4991, Total Reward: 10
# Episode: 4992, Total Reward: 11
# Episode: 4993, Total Reward: 12
# Episode: 4994, Total Reward: 6
# Episode: 4995, Total Reward: 5
# Episode: 4996, Total Reward: 10
# Episode: 4997, Total Reward: 5
# Episode: 4998, Total Reward: 9
# Episode: 4999, Total Reward: 8
# Episode: 5000, Total Reward: 9

# %% [markdown]
# ## Exersice 1.2: Evaluate Q-learning
#
# Here implement greedy actions only with the learned Q-table. It is also possible to visualize the results. A coorectly implemented q-learning algorithm should get average reward of higher then 7.

# %%
# Evaluate the trained policy
env_render = gym.make("Taxi-v3", render_mode='human') # env with renderig, if you want to visualize, but it is slow. 

total_rewards = []
num_evaluation_episodes = 100

for _ in range(num_evaluation_episodes):
    state, _ = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        # Choose greedy action 
        
        action = np.argmax(q_table[state, :])
        new_state, reward, terminated, truncated, _ = env.step(action)
        #new_state, reward, terminated, truncated, _ = env_render.step(action) # uncomment for visualization

        done = terminated or truncated
        total_reward += reward
        state = new_state
    
    total_rewards.append(total_reward)

average_reward = np.mean(total_rewards)
print(f"Average Reward over {num_evaluation_episodes} evaluation episodes: {average_reward}")
env_render.close()
# Out:
# Average Reward over 100 evaluation episodes: 7.53

# %% [markdown]
# ## Exersice 1.3: Q-learning question
#
# Are there any limitations with Q-learning, what type of problems can it solve and what type of problems is it less suitable for?

# %% [markdown]
# 1- limitaions with Q-learning ?
# 2- type of problems can solve with Q-learning ?
# 3- type of problems less suitable for ?
#
# | Aspect | Q-Learning |
# |---|---|
# | **Good at** | Works best when there are only a few options to remember. Good for simple problems. |
# | **Not good at** | Struggles with big problems with lots of options. Can be slow to learn in these cases. |
# | **Needs** | Doesn't need much computer power. |
# | **Learning** | Learns each option separately. |
#
# So, Q-learning is good for simple problems where there are only a few options to remember. It doesn’t need much computer power. But if there are lots of options, Q-learning can be slow because it learns each option one by one

# %% [markdown]
# # Deep Q learning
#
# In this task, we'll tackle the challenge of balancing an inverted pendulum. What makes this problem intriguing is that it involves continuous input variables, making the traditional Q-learning approach with a finite table impractical. Instead, we'll use a neural network to approximate the Q-table, enabling us to efficiently handle continuous input while still producing discrete outputs.
#
# First we will construct our neural network, this will be done in three steps. First we will define our activation function, then we will define a what a layer is and lastly we will construct the network.
#
# First let us go over the math of a neural network. They should be seen as general function approximator. A segment of neural network can be represented with a graph representation, see image below.
#
# <img src="imgs/NN_ps3.png" width="800"/>
#
#
#
# ### Naming
# * $a^i_j$ is the output of neuron j in layer i.
# * $b^i_j$ is the sum of the input to neuron j in layer i.
# * $g()$ is the activation function of a neuron (the last layer does not have a activation funciton in this case)
# * $w^i_{jk}$ is the weights of layer i going from neron k in layer i-1 to neuron j in layer i.
#
# ### Forward propagation
#
# A neural network can be seen as a function $y = f(x)$ where $x$ is an input vector and $y$ is an output vector. Forward propagation describes how we go from the input $x$ to the output $y$. Each layer can be caluculated in a sequence, where we start from the input.
#
# First each neuron $j$ in layer 1 calculated the sum of the input to that neuron:
#
# $b^1_j = \sum_{k=1}^{len(x)}( w^1_{j,k}x_k) + w^1_{j,0}$
#
# The output of the first layer is caluclated but using the activation funciton.
#
# $a^1_j = g(b^1_j)$
#
# More generally for layer $i$ and with matrix multiplication we can write this as.
#
# $b^i = w^i \begin{bmatrix} 1 \\ a^{i-1}\end{bmatrix}$
#
# where $b^i$ is a vector that has the same dimension as number of neurons in layer $i$ and the 1 added to the input is for calculating the bias.
#
# $a^i = g(b^i)$
#
# This is then caluculated sequentially until the last layer has been reashed. For the last layer without activation function we would have
#
# $\hat{y} = a^i = b^i$
#
# ### Backward propagation
#
# The way we train a network is by updating the weights $w$, they are the parameters we want to estimate to solve the problem. The way we are going to update the weights is through gradient descent. The gradients are calculated sequentially from the last layer to the first. The reason for this is that this allows us to leverage the chain rule, this saves us a lot of computational complexity.
#
# Calculating gradients:
#
# For each parameter (weight) in the neural network we will calculate a gradient:
# $\frac{\partial \mathcal{L}}{\partial w^i_{jk}}$
# where $\mathcal{L(\mathbf{y}, \hat{\mathbf{y}})}$ is the loss function, which we want to minimize. A normal loss function could for example be the mean square error $\mathcal{L} = \frac{1}{n}\sum_{i=1}^n(y-\hat{y})^2$. The gradients can be caluclated with
#
# $\frac{\partial \mathcal{L}}{\partial w^i_{jk}} = \Delta^i_{j} a^{i-1}_k$
#
# where $\Delta^i_j$ can be seen as the "precived" error for the input to neuron $j$ in layer $i$. It can be calculated with the chain rule. Let $n(i)$ be a function that returns the number of neuron of layer $i$.
#
# $\Delta^i_j = \left( \sum_{r=1}^{n(i+1)} \Delta^{i+1}_r w^{i+1}_{rj} \right) \frac{\partial g(b^i_j)}{\partial b^i_j}$
#
# For the first itteration there where is no $\Delta^{i+1}_r$ then they are calculated as:
#
# $\Delta^i_j = \frac{\partial \mathcal{L(\mathbf{y}, \hat{\mathbf{y}})}}{\partial \hat{y}_j}$
#
# This is under the assumption that there is no activation on the last layer. The nice thing is that the calculation of the vector $\Delta^i$ can be done as a matrix multiplication:
#
# $\Delta^i = (w^{i+1})^T \Delta^{i+1} \odot \nabla_{b^i} g(b^i)$
#
# where $\odot$ is elementwise multiplication and $\nabla_{b^i} g(b^i) = \begin{bmatrix} \frac{\partial g(b^i_1)}{\partial b^i_1} &...&\frac{\partial g(b^i_n)}{\partial b^i_n} \end{bmatrix}^T$.
#
# We can then calculate the gradients for a layer with:
#
# $\nabla_{w^i} \mathcal{L} = \Delta^i  (a^{i-1})^T$
#
# We are then going to update the weights with:
#
# $w^i \leftarrow w^i - \alpha(\nabla_{w^i} \mathcal{L} + \lambda w^i)$
#
# where $\alpha$ is the learning rate and $\lambda$ is a regularization term (L2 regularization), we don't want the weight to become too large. The regularization also combats overfitting to some extent. We will come back to $\nabla_{w^i}$ later.
#
# For more on the chain rule see the exersice "NN_exersice.zip" on canvas under the Exercises folder.

# %% [markdown]
# ## Exersice 2.1: ReLu
#
# Here we will implement a class for the ReLu activation function. The activation function is what allows deep neural networks to express non-linearities. The class will only have two functions, forward(x) and diff(x). The forward function takes a vector or matrix and outputs the same shape where for every element we have applied the ReLu function. The diff function returns the partial derivative of the ReLu function. This will later be used in our neural network.
#
# Hint: np.where() is useful function

# %%
class ReLu():
    def forward(self, x):
        # x is a numpy array and can have any shape. 
        # calculates the output of the ReLU function
        return np.maximum(x,0)
        
        
    def diff(self, x):
        # x is a numpy array and can have any shape.
        # calculates the partial differential of the ReLU function
        return np.where(x <= 0, 0 , 1)

# %%
relu = ReLu()

input = np.array([[1.2],[-1.1], [0.0], [10.3]])
out = relu.forward(input)
ref = np.array([[1.2],[0.0], [0.0], [10.3]])
print('forward test: ', np.array_equal(out, ref))

diff_out = relu.diff(input)
diff_ref = np.array([[1.],[0.0], [0.0], [1]])
print('diff test: ', np.array_equal(diff_out, diff_ref))
# Out:
# forward test:  True
# diff test:  True

# %% [markdown]
# ## Exersice 2.2: Layer
#
# A dense neural network is constructed by layers of neurons, here we will define a class to represent our layers. It will contain the weights and activation function for the layer. The layer class will contain two functions, forward and backward.
#
# Hint: it is a good practice to return a copy of np arrays or matrices as otherwise modifying the output can modify the internally saved matrix as it is the same object, these problems are not easy to debug. For a matrix A, then return A.copy().

# %%
class Layer(object):
    def __init__(self, num_in, num_out, activation_func=None):
        self.weights = np.random.rand(num_out, num_in+1) - 0.5  # (to layer, from layer)
        self.gradients = np.zeros((num_out, num_in+1))
        self.a_input = None  # placeholder for saving the input to the forward function
        self.b = None  # placeholder for saving the value right before the activation function
        self.activation_func = activation_func  # class instance of activation function

    def forward(self, x):
        # Add a 1 for the bias term on the input and save it in self.a_input, this will be used in backward()
        self.a_input = np.vstack([np.ones((1, x.shape[1])), x])

        # Calculate b, the summation in each neuron, using matrix multiplication, and save it in self.b
        self.b = np.dot(self.weights, self.a_input)

        # If the activation function is not None, run the forward of the activation function
        if self.activation_func is not None:
            return self.activation_func.forward(self.b)
        else:
            return self.b

    def backward(self, pre_delta, pre_w=None):
        # pre_delta is from layer i+1, pre_w is the weights from layer i+1.
        # First check if pre_w is None, it is None for the last layer (output layer).
        if self.activation_func is None:
            delta = pre_delta.copy()
            self.gradients = np.dot(delta, self.a_input.T)
            return delta

        if pre_w is not None:
            # Calculate pre_delta if pre_w is not None
            pre_delta = np.dot(pre_w.T, pre_delta)

            if self.activation_func is not None:
                # Add bias term and calculate the derivative of the activation function
                add_bias = np.vstack([np.ones((1, self.b.shape[1])), self.b])
                pre_delta *= self.activation_func.diff(add_bias)

        # Calculate this layer's delta
        delta = pre_delta[1:]

        # Calculate this layer's gradients and save in self.gradients (do not apply the gradients)
        self.gradients = np.dot(delta, self.a_input.T)

        # Return delta from this layer
        return delta
        # Hint: see calculations above under Deep Q Learning

# %% [markdown]
# ### Test your layer

# %%
### ------------ Test forward -------------------

layer = Layer(3, 3, ReLu())
x = np.array([[1.2], [-0.3], [4.1]])
weights = np.array([[ 0.27611978, -0.34896471, -0.33349842,  0.33546291],
          [-0.17959862, -0.36556547,  0.26716984,  0.31734925],
          [-0.11004516,  0.28841945, -0.36654527, -0.10927562]])
layer.weights = weights
ref = np.array([[1.33280959],
             [0.60270379],
             [0.        ]])
out = layer.forward(x)

if np.allclose(ref, out):
    print('Forward function matches reference')
else:
    print('Forward is not same as reference', out)

### ------------ Test Backward with no activation function -------------------
layer = Layer(3, 3)
layer.weights = weights

out = layer.forward(x)

pre_delta = np.array([[0.0],[0.3],[-1.7]])
delta = layer.backward(pre_delta)

if np.allclose(pre_delta, delta):
    print('delta is correct for no activation function')
else:
    print('delta is incorrect for no activation function', delta)

    
grad_ref = np.array([[ 0.,    0.,   -0.,    0.  ],
                     [ 0.3,   0.36, -0.09,  1.23],
                     [-1.7, -2.04, 0.51,-6.97]])

if np.allclose(grad_ref, layer.gradients):
    print('gradients are correct for when no activation function')
else:
    print('gradients are incorrect for when no activation function', layer.gradients)
    
### ------------ Test Backward with activation function -------------------
    
layer = Layer(3, 3, ReLu())
layer.weights = weights

out = layer.forward(x)

pre_w  = np.array([[-0.04031945,  0.36892667, -0.47157759, -0.19271963],
                   [ 0.25223295,  0.38480469,  0.42154434,  0.13994889],
                   [ 0.07775184, -0.43675348,  0.36158881,  0.25008313]])

delta = layer.backward(pre_delta, pre_w)

ref_delta = np.array([[ 0.85792232],
                      [-0.48823767],
                      [-0.        ]])

ref_grad = np.array([[ 0.85792232,  1.02950679, -0.2573767, 3.51748152],
                     [-0.48823767, -0.58588521,  0.1464713,  -2.00177447],
                     [-0.,         -0.,          0.,         -0.       ]])

if np.allclose(ref_delta, delta):
    print('delta correct with activation function')
else:
    print('delta incorrect with activation function', delta)
    
if np.allclose(ref_grad, layer.gradients):
    print('gradients are correct with activation function')
else:
    print('gradients are incorrect with activation function', layer.gradients)
# Out:
# Forward function matches reference
# delta is correct for no activation function
# gradients are correct for when no activation function
# delta correct with activation function
# gradients are correct with activation function

# %% [markdown]
# ## Exercise 2.3: Define the neural network
# We will create a neural network that has two hidden layers with 64 neurons each with ReLU activation function and the output layer has the same size as the number of outputs but with no activation function.

# %%
class NeuralNetwork():
    def __init__(self, lr=1e-3, input_size=4, output_size=6, regularization=1e-4):
        # Here we create a list of the layers that we defined above
        # This is where we define the structure of our network
        self.layers = [Layer(input_size, 64, ReLu()),
                       Layer(64, 64, ReLu()),
                       Layer(64, output_size)]
        self.num_layers = len(self.layers)
        self.lr = lr
        self.regularization = regularization
        
    def forward(self, x):
        # Calculate the output of the neural network by iterating over the layers and return the output.
        for i in self.layers:
            x = i.forward(x)
        return x
    
    def backward(self, loss_diff):
        # Here we calculate the gradients.
        # The input is the partial differential of the loss function. 
        # Go backward through the layers and call the backward function from the last layer and iterate 
        # towards the first layer.
        gradients = [None] * self.num_layers  # initialize a python list to hold the gradients 
        
        # Enter your solution
        delta = loss_diff
        for i, layer in reversed(list(enumerate(self.layers))):
           
            pre_w = None if i == self.num_layers - 1 else self.layers[i + 1].weights
            delta = layer.backward(delta, pre_w)
            gradients[i] = layer.gradients
        
        return gradients
    
    def update_weights(self, gradients):
        # Here we update the weights of the network, input is a list of gradients. We then want to update the weights
        # as described above with regularization. 
        # the second thing we are going to do is to clip the weights, this just ensures that we won't get any 
        # numerical problems from exploding gradients. 
        for i, grad in enumerate(gradients): 
            # UPDATE the weights here
            regularization_term = self.regularization * self.layers[i].weights
            self.layers[i].weights -= self.lr * (grad + regularization_term)
            self.layers[i].weights = np.clip(self.layers[i].weights, -1e4, 1e4)

# %% [markdown]
# ## Test supervised learning to see if the network performes as expeced.
# Here we want to test the neural network on a simple supervised problem, it should learn the output of two functions. Does the y_est follow the true y? You should see that they follow each other fairly well, usually within 0.1 difference.

# %%
nn = NeuralNetwork(lr=1e-3, input_size=3, output_size=2)
# Train 
for i in range(10000):
    x = np.random.rand(3,1)
    y1 = 2*x[0,0] + x[0,0]*x[1,0] +1
    y2= -1*x[2,0] + 3*x[0,0]*x[2,0] 
    
    y = np.array([[y1],[y2]])
    y_est = nn.forward(x)
    
    diff_loss = -2*(y-y_est)
    loss = (y-y_est)**2
    grad = nn.backward(diff_loss)
    nn.update_weights(grad)

# Test
for i in range(5):
    x = np.random.rand(3,1)
    y1 = 2*x[0,0] + x[0,0]*x[1,0] +1
    y2= -1*x[2,0] + 3*x[0,0]*x[2,0] 
    
    y = np.array([[y1],[y2]])
    y_est = nn.forward(x)
    
    print('y:', y[:,0], 'y_est:', y_est[:,0])
# Out:
# y: [2.22158738 0.26678883] y_est: [2.22314244 0.32747088]
# y: [3.35104495 0.60093147] y_est: [3.39692558 0.57657841]
# y: [2.27013676 0.18607162] y_est: [2.23761253 0.22550598]
# y: [2.98974132 0.15337377] y_est: [2.97528171 0.12660702]
# y: [3.03440449 0.30754836] y_est: [3.08689468 0.30482666]

# %% [markdown]
# ## Training Deep Q-learning
#
# The idea for this section is that we will walk you through the code and the process and then you will answer some theoretical questions.
#
# Now, we have a neural network, and we aim to employ it to balance an inverted pendulum on a cart. This problem involves continuous input space, with four inputs, and a discrete output space, consisting of two possible actions (left or right). The reward function for this task is straightforward - we receive a reward for every step taken, with the objective being to maintain balance. The task is considered unsuccessful if the pendulum leans too far or the cart moves excessively to the side. You can find more details about this problem at https://gymnasium.farama.org/environments/classic_control/cart_pole/.
#
# The challenge with this problem is that the continuous input space makes it impractical to use standard Q-learning, as the Q-table would become excessively large. To address this, we'll replace the Q-table with a neural network. However, as we will demonstrate, this transition is not without its challenges.
#
# The primary challenge in deep Q-learning lies in training stability, as the training process tends to be noisy, and many issues can arise. To enhance stability, we introduce three key components: target networks, experience replay, and batch gradient descent. However, before delving into those specifics, let's discuss the fundamental principle of replacing the Q-table with a neural network.
#
# In Q-learning, we maintain a table of future expected rewards, and for a given state and action, we can obtain the value, denoted as $Q(s, a)$. Our objective is to approximate this Q-value using a neural network, denoted as $f$, which takes the state as input and produces a value for each possible action, i.e., $\hat{q} = f(s)$, where $\hat{q}$ is a vector. The training loop remains similar to traditional Q-learning, but in this case, we formulate a loss function.
#
# $\mathcal{L}(s_t, a) = (q(s_t)_a -\hat{q}(s_t)_a)^2$
#
# were
#
# $q(s_t)_a = r + \gamma \underbrace{\max}_{a} \hat{q}(s_{t+1})$
#
# and $\hat{q}(s_t)_a$ is the output of the network for that action and state, and $\hat{q}(s_{t+1})$ is for the next state. This will make the network converge towarde the Q-table, atleast theoretically. The problem is that this is prone to instabilities. We can no longer initiate the network to predict zeros initially, so the initial predictions of the future reward will be completely wrong. Every time we update the weights we will also change $\underbrace{\max}_{a} \hat{q}(s_{t+1})$, that the value the network tries to converge to is allways changing, and if it varies to fast instabilities will arrise. One of the downsides of using gradient decent is that it can easily forget thing that it trained on a long time ago. The methods below attempts to minimize these issues.
#
#
# ### Target network
# The idea here is to make $\underbrace{\max}_{a} \hat{q}(s_{t+1})$ a slow varying target to increase stability. We introdue a second network called the target network. So we have two netorks $\hat{q} = f(s)$ and $\hat{q}_T = f_T(s)$, where the second is the target network. We use the second network to estimate the future estimated reward.
#
# $q(s_t, a) = r + \gamma \underbrace{\max}_{a} \hat{q}_T(s_{t+1}, a)$
#
# The idea is then to update the target network slowly towards the first network, the weights of the target network $w_T$ can then be updated with
#
# $w_T = w_T + \alpha_T (w - w_T)$
#
# where $\alpha_T$ is the target update rate. This adds stability to the traning as the future expected reward is more steady and slow changing.
#
# ### Experiance replay
#
# Next up is experience replay, because of gradient descent we don't want to train on samples that are too close to each other as there is a risk that the network will forget things it has learned. The idea is then in the training loop to not directly train on the observed data but instead save it in a buffer/queue. For training we sample for the queue, this means that the network might train on old data or new data. This minimizes that it forgets or that a lot of samples in sequence are too similar.
#
# ### Batch gradient decent
#
# To furter imporove stability we sample multiple timesteps from our memory buffer, then we caluclate the gradients for each of them and take the average of the gradients. It is then those average graidentes we use as $\nabla_{w^i}$ to update the weights, this minimize noise as each update of the weights is based on multiple data samples.
#
# We will now show how these things can be implemented in code.
#
# ## Hyper parameters
#
# Neural networks can have quite a few hyper parameters and it can be quite tricky to tune them. I have provided some hypter parameters that work, but feel free to tune them if desiered.

# %%
import random
import copy
from collections import deque # will be used to create a memory buffer

n_observation = 4 # input size, inverted pendelum (Cart Pole) 
n_actions = 2 # output size, inverted pendelum (Cart Pole)

# Hyperparameters
learn_rate = 2e-4 # learning rate, alpha
discount_factor = 0.98 # discount factor, gamma 
epsilon = 1.0 # epsilon
epsilon_max = 1.0 # epsilon max
epsilon_min = 0.05 # epsilon min
# epsilon_decay = epsilon_max - epsilon_min * 0.1
epsilon_lambda = 0.01 # epsilon decay rate
target_rate = 5e-3 # learning rate of target network
num_episodes = 1000 # number of episodes the learning is 
batch_size = 128 # How many samples are used to calculate the gradients. 
regularization = 1e-4 # amount of regularization

# %% [markdown]
# ## Training function
#
# Here we define our training function, this is what will be called for every step in our trianing loop. This part is responsible for sampling a batch from the memory buffer and calculating the gradients for the batch, it is also here we have our reward function and update our network. Lastly we will update the weights of the target network.

# %%
def unpack_state(state): #this is for reshaping the state from gym to a standing vector. 
    return  np.reshape(state, (len(state),1))

# This is the training function that will be called from the traning loop
def train_network(nn, nn_target, memory):
    # nn - is the neural network, nn_target - is the target network, memory - is the memory buffer
    if len(memory) > batch_size: #check if there is enought data in the memory buffer
        grad_list = [[] for x in range(nn.num_layers)] # create a list to temporay store all the gradients
        sample = random.sample(memory, batch_size) # We sample batch_size number of samples from our memory buffer

        # we calculate the gradients for each sample that we sampled
        for i in range(batch_size): 
            state = sample[i][0]
            action = sample[i][1]
            reward = sample[i][2]
            next_state = sample[i][3]
            done = sample[i][4]
            
            # first we run a forward pass on both networks 
            pred = nn.forward(unpack_state(state))
            pred_target = nn_target.forward(unpack_state(next_state))
            
            # we create a loss vector that is zeros. We directly express it as the partial deriviative 
            diff_loss = np.zeros((n_actions,1))
            
            # we calcualte out q using the reward and the best expected reward from the target network
            q = reward + discount_factor * np.max(pred_target)*(1-done)
            # we caluclate the partial derivative loss for the action 
            diff_loss[action, 0] =  -2*(q - pred[action, 0])
        
            grad = nn.backward(diff_loss) # we calculate the gradients in the network
            
            # we append the gradients to our list for the batch 
            for k in range(nn.num_layers):
                    grad_list[k].append(grad[k])

        # After all gradients are calcultated we take the average over the batch. 
        avg_grad = []            
        for k in range(nn.num_layers):
            avg_grad.append(np.mean(grad_list[k], axis=0))
        
        # we update the weigths of the networḱ
        nn.update_weights(avg_grad)
    # Lastly we update the target network to be closer to the network, the idea is that the target updates slower
    # and therefore is less noisy. 
    for k in range(nn.num_layers):
            nn_target.layers[k].weights += target_rate*(nn.layers[k].weights - nn_target.layers[k].weights)
    return

# %% [markdown]
# ##  Training loop
#
# Here is the actual training loop that runs the simulation. This part should look similar to the q-learning training loop at the beginning of the assignment. The difference is the call of the training function and appending to the memory buffer. Because of the unstable nature of deep Q-learning, you typically save the network that performed the best during training. It can sometimes take more than 100 episodes before you see any noticeable learning.
#
# Even with all the additions of the target network, batch gradient decent and experience replay, the training can still be unstable. It is therefore common in reinforcement learning to always save the best-performing network.
#
# ## Exercise 2.4: Epsilon greedy - deep learning
# Fill code for action and update of epsilon.

# %%
# Train Deep Q-learning algorithm

# We create the environment 
env = gym.make("CartPole-v1")
#env = gym.make('LunarLander-v2')
# we create our neural network and target network, both are identical to start with. 
nn = NeuralNetwork(lr=learn_rate, input_size=n_observation, output_size=n_actions, regularization=regularization)
nn_target = NeuralNetwork(lr=learn_rate, input_size=n_observation, output_size=n_actions, regularization=regularization)
nn_target.layers = nn.layers.copy()

# A placeholder network to save the best solution. 
nn_save = NeuralNetwork(lr=learn_rate, input_size=n_observation, output_size=n_actions, regularization=regularization)

# our memory buffer, it can hold 10000 samples 
memory = deque(maxlen=10000)

# To track rewards
rewards_list = []
highest_score = 0

# train over a number of episodes
for episode in range(num_episodes):
    state, info = env.reset() # reset the environment in the beging of every episode
    done = False
    total_reward = 0

    while not done:
        # Get prediciton
        pred = nn.forward(unpack_state(state))
        
        # Calculate action with exploration-exploitation trade-off
        # action = ...


        # #action = env.action_space.sample() if np.random.rand() < epsilon else np.argmax(pred) this is not correct Soheb
        if np.random.uniform(0, 1) < epsilon:
            action = env.action_space.sample()  
        else:
            action = np.argmax(pred)  
        

        
        new_state, reward, terminated, truncated, _ = env.step(action) # take a step in the environment
        done = terminated or truncated # check if done
        # append to the memory buffer
        memory.append((state, action, reward, new_state, done))
        
        # call the training function
        train_network(nn, nn_target, memory)

        # update total reward and state
        total_reward += reward 
        state = new_state
        
            
    rewards_list.append(total_reward)
    # save best performing network
    if total_reward >= np.max(rewards_list):
        nn_save = copy.deepcopy(nn)
        print('save_model', total_reward)
        
    # Decay exploration probability (epsilon)
    
    
    epsilon = max(epsilon_min, epsilon * np.exp(-epsilon_lambda * episode)) #which one is more accurat
    

    print(f"Episode: {episode+1}, Total Reward: {total_reward}", 'prob ', epsilon)
# Out:
# save_model 34.0
# Episode: 1, Total Reward: 34.0 prob  1.0
# Episode: 2, Total Reward: 33.0 prob  0.9900498337491681
# Episode: 3, Total Reward: 13.0 prob  0.9704455335485082
# Episode: 4, Total Reward: 16.0 prob  0.9417645335842487
# Episode: 5, Total Reward: 20.0 prob  0.9048374180359595
# Episode: 6, Total Reward: 22.0 prob  0.8607079764250578
# Episode: 7, Total Reward: 19.0 prob  0.8105842459701871
# Episode: 8, Total Reward: 24.0 prob  0.7557837414557255
# Episode: 9, Total Reward: 27.0 prob  0.697676326071031
# save_model 37.0
# Episode: 10, Total Reward: 37.0 prob  0.6376281516217732
# Episode: 11, Total Reward: 28.0 prob  0.5769498103804865
# Episode: 12, Total Reward: 16.0 prob  0.5168513344916991
# Episode: 13, Total Reward: 27.0 prob  0.45840601130522335
# Episode: 14, Total Reward: 31.0 prob  0.4025242240336358
# Episode: 15, Total Reward: 30.0 prob  0.3499377491111552
# Episode: 16, Total Reward: 27.0 prob  0.30119421191220197
# Episode: 17, Total Reward: 14.0 prob  0.25666077695355577
# Episode: 18, Total Reward: 27.0 prob  0.21653566731600699
# save_model 52.0
# Episode: 19, Total Reward: 52.0 prob  0.18086579261712202
# Episode: 20, Total Reward: 33.0 prob  0.14956861922263498
# Episode: 21, Total Reward: 24.0 prob  0.12245642825298185
# Episode: 22, Total Reward: 11.0 prob  0.0992612515596456
# Episode: 23, Total Reward: 9.0 prob  0.07965902028589798
# Episode: 24, Total Reward: 11.0 prob  0.06329176835964069
# Episode: 25, Total Reward: 10.0 prob  0.05
# Episode: 26, Total Reward: 11.0 prob  0.05
# Episode: 27, Total Reward: 11.0 prob  0.05
# Episode: 28, Total Reward: 8.0 prob  0.05
# Episode: 29, Total Reward: 10.0 prob  0.05
# Episode: 30, Total Reward: 8.0 prob  0.05
# Episode: 31, Total Reward: 10.0 prob  0.05
# Episode: 32, Total Reward: 9.0 prob  0.05
# Episode: 33, Total Reward: 10.0 prob  0.05
# Episode: 34, Total Reward: 8.0 prob  0.05
# Episode: 35, Total Reward: 8.0 prob  0.05
# Episode: 36, Total Reward: 11.0 prob  0.05
# Episode: 37, Total Reward: 10.0 prob  0.05
# Episode: 38, Total Reward: 13.0 prob  0.05
# Episode: 39, Total Reward: 10.0 prob  0.05
# Episode: 40, Total Reward: 10.0 prob  0.05
# Episode: 41, Total Reward: 10.0 prob  0.05
# Episode: 42, Total Reward: 11.0 prob  0.05
# Episode: 43, Total Reward: 10.0 prob  0.05
# Episode: 44, Total Reward: 11.0 prob  0.05
# Episode: 45, Total Reward: 8.0 prob  0.05
# Episode: 46, Total Reward: 9.0 prob  0.05
# Episode: 47, Total Reward: 12.0 prob  0.05
# Episode: 48, Total Reward: 10.0 prob  0.05
# Episode: 49, Total Reward: 10.0 prob  0.05
# Episode: 50, Total Reward: 8.0 prob  0.05
# Episode: 51, Total Reward: 8.0 prob  0.05
# Episode: 52, Total Reward: 9.0 prob  0.05
# Episode: 53, Total Reward: 8.0 prob  0.05
# Episode: 54, Total Reward: 10.0 prob  0.05
# Episode: 55, Total Reward: 10.0 prob  0.05
# Episode: 56, Total Reward: 10.0 prob  0.05
# Episode: 57, Total Reward: 9.0 prob  0.05
# Episode: 58, Total Reward: 10.0 prob  0.05
# Episode: 59, Total Reward: 11.0 prob  0.05
# Episode: 60, Total Reward: 10.0 prob  0.05
# Episode: 61, Total Reward: 10.0 prob  0.05
# Episode: 62, Total Reward: 9.0 prob  0.05
# Episode: 63, Total Reward: 8.0 prob  0.05
# Episode: 64, Total Reward: 10.0 prob  0.05
# Episode: 65, Total Reward: 12.0 prob  0.05
# Episode: 66, Total Reward: 9.0 prob  0.05
# Episode: 67, Total Reward: 9.0 prob  0.05
# Episode: 68, Total Reward: 11.0 prob  0.05
# Episode: 69, Total Reward: 10.0 prob  0.05
# Episode: 70, Total Reward: 12.0 prob  0.05
# Episode: 71, Total Reward: 10.0 prob  0.05
# Episode: 72, Total Reward: 11.0 prob  0.05
# Episode: 73, Total Reward: 9.0 prob  0.05
# Episode: 74, Total Reward: 11.0 prob  0.05
# Episode: 75, Total Reward: 11.0 prob  0.05
# Episode: 76, Total Reward: 11.0 prob  0.05
# Episode: 77, Total Reward: 12.0 prob  0.05
# Episode: 78, Total Reward: 12.0 prob  0.05
# Episode: 79, Total Reward: 13.0 prob  0.05
# Episode: 80, Total Reward: 10.0 prob  0.05
# Episode: 81, Total Reward: 12.0 prob  0.05
# Episode: 82, Total Reward: 10.0 prob  0.05
# Episode: 83, Total Reward: 10.0 prob  0.05
# Episode: 84, Total Reward: 14.0 prob  0.05
# Episode: 85, Total Reward: 12.0 prob  0.05
# Episode: 86, Total Reward: 10.0 prob  0.05
# Episode: 87, Total Reward: 15.0 prob  0.05
# Episode: 88, Total Reward: 13.0 prob  0.05
# Episode: 89, Total Reward: 10.0 prob  0.05
# Episode: 90, Total Reward: 12.0 prob  0.05
# Episode: 91, Total Reward: 13.0 prob  0.05
# Episode: 92, Total Reward: 10.0 prob  0.05
# Episode: 93, Total Reward: 10.0 prob  0.05
# Episode: 94, Total Reward: 13.0 prob  0.05
# Episode: 95, Total Reward: 10.0 prob  0.05
# Episode: 96, Total Reward: 14.0 prob  0.05
# Episode: 97, Total Reward: 11.0 prob  0.05
# Episode: 98, Total Reward: 12.0 prob  0.05
# Episode: 99, Total Reward: 11.0 prob  0.05
# Episode: 100, Total Reward: 14.0 prob  0.05
# Episode: 101, Total Reward: 11.0 prob  0.05
# Episode: 102, Total Reward: 11.0 prob  0.05
# Episode: 103, Total Reward: 9.0 prob  0.05
# Episode: 104, Total Reward: 11.0 prob  0.05
# Episode: 105, Total Reward: 12.0 prob  0.05
# Episode: 106, Total Reward: 12.0 prob  0.05
# Episode: 107, Total Reward: 13.0 prob  0.05
# Episode: 108, Total Reward: 10.0 prob  0.05
# Episode: 109, Total Reward: 11.0 prob  0.05
# Episode: 110, Total Reward: 9.0 prob  0.05
# Episode: 111, Total Reward: 10.0 prob  0.05
# Episode: 112, Total Reward: 11.0 prob  0.05
# Episode: 113, Total Reward: 11.0 prob  0.05
# Episode: 114, Total Reward: 14.0 prob  0.05
# Episode: 115, Total Reward: 11.0 prob  0.05
# Episode: 116, Total Reward: 12.0 prob  0.05
# Episode: 117, Total Reward: 14.0 prob  0.05
# Episode: 118, Total Reward: 17.0 prob  0.05
# Episode: 119, Total Reward: 13.0 prob  0.05
# Episode: 120, Total Reward: 13.0 prob  0.05
# Episode: 121, Total Reward: 15.0 prob  0.05
# Episode: 122, Total Reward: 15.0 prob  0.05
# Episode: 123, Total Reward: 13.0 prob  0.05
# Episode: 124, Total Reward: 11.0 prob  0.05
# Episode: 125, Total Reward: 12.0 prob  0.05
# Episode: 126, Total Reward: 12.0 prob  0.05
# Episode: 127, Total Reward: 17.0 prob  0.05
# Episode: 128, Total Reward: 14.0 prob  0.05
# Episode: 129, Total Reward: 12.0 prob  0.05
# Episode: 130, Total Reward: 16.0 prob  0.05
# Episode: 131, Total Reward: 11.0 prob  0.05
# Episode: 132, Total Reward: 17.0 prob  0.05
# Episode: 133, Total Reward: 12.0 prob  0.05
# Episode: 134, Total Reward: 12.0 prob  0.05
# Episode: 135, Total Reward: 11.0 prob  0.05
# Episode: 136, Total Reward: 11.0 prob  0.05
# Episode: 137, Total Reward: 11.0 prob  0.05
# Episode: 138, Total Reward: 9.0 prob  0.05
# Episode: 139, Total Reward: 9.0 prob  0.05
# Episode: 140, Total Reward: 14.0 prob  0.05
# Episode: 141, Total Reward: 9.0 prob  0.05
# Episode: 142, Total Reward: 13.0 prob  0.05
# Episode: 143, Total Reward: 13.0 prob  0.05
# Episode: 144, Total Reward: 13.0 prob  0.05
# Episode: 145, Total Reward: 10.0 prob  0.05
# Episode: 146, Total Reward: 13.0 prob  0.05
# Episode: 147, Total Reward: 15.0 prob  0.05
# Episode: 148, Total Reward: 12.0 prob  0.05
# Episode: 149, Total Reward: 12.0 prob  0.05
# Episode: 150, Total Reward: 11.0 prob  0.05
# Episode: 151, Total Reward: 19.0 prob  0.05
# Episode: 152, Total Reward: 10.0 prob  0.05
# Episode: 153, Total Reward: 14.0 prob  0.05
# Episode: 154, Total Reward: 11.0 prob  0.05
# Episode: 155, Total Reward: 11.0 prob  0.05
# Episode: 156, Total Reward: 21.0 prob  0.05
# Episode: 157, Total Reward: 14.0 prob  0.05
# Episode: 158, Total Reward: 12.0 prob  0.05
# Episode: 159, Total Reward: 14.0 prob  0.05
# Episode: 160, Total Reward: 18.0 prob  0.05
# Episode: 161, Total Reward: 14.0 prob  0.05
# Episode: 162, Total Reward: 20.0 prob  0.05
# Episode: 163, Total Reward: 22.0 prob  0.05
# Episode: 164, Total Reward: 17.0 prob  0.05
# Episode: 165, Total Reward: 20.0 prob  0.05
# Episode: 166, Total Reward: 17.0 prob  0.05
# Episode: 167, Total Reward: 14.0 prob  0.05
# Episode: 168, Total Reward: 24.0 prob  0.05
# Episode: 169, Total Reward: 20.0 prob  0.05
# Episode: 170, Total Reward: 19.0 prob  0.05
# Episode: 171, Total Reward: 21.0 prob  0.05
# Episode: 172, Total Reward: 17.0 prob  0.05
# Episode: 173, Total Reward: 14.0 prob  0.05
# Episode: 174, Total Reward: 15.0 prob  0.05
# Episode: 175, Total Reward: 17.0 prob  0.05
# Episode: 176, Total Reward: 22.0 prob  0.05
# Episode: 177, Total Reward: 17.0 prob  0.05
# Episode: 178, Total Reward: 36.0 prob  0.05
# Episode: 179, Total Reward: 26.0 prob  0.05
# Episode: 180, Total Reward: 25.0 prob  0.05
# Episode: 181, Total Reward: 16.0 prob  0.05
# Episode: 182, Total Reward: 20.0 prob  0.05
# Episode: 183, Total Reward: 28.0 prob  0.05
# Episode: 184, Total Reward: 12.0 prob  0.05
# Episode: 185, Total Reward: 13.0 prob  0.05
# Episode: 186, Total Reward: 13.0 prob  0.05
# Episode: 187, Total Reward: 14.0 prob  0.05
# Episode: 188, Total Reward: 14.0 prob  0.05
# Episode: 189, Total Reward: 16.0 prob  0.05
# Episode: 190, Total Reward: 39.0 prob  0.05
# Episode: 191, Total Reward: 18.0 prob  0.05
# Episode: 192, Total Reward: 18.0 prob  0.05
# Episode: 193, Total Reward: 18.0 prob  0.05
# Episode: 194, Total Reward: 16.0 prob  0.05
# Episode: 195, Total Reward: 17.0 prob  0.05
# Episode: 196, Total Reward: 17.0 prob  0.05
# Episode: 197, Total Reward: 12.0 prob  0.05
# Episode: 198, Total Reward: 20.0 prob  0.05
# Episode: 199, Total Reward: 17.0 prob  0.05
# Episode: 200, Total Reward: 14.0 prob  0.05
# Episode: 201, Total Reward: 12.0 prob  0.05
# Episode: 202, Total Reward: 13.0 prob  0.05
# Episode: 203, Total Reward: 22.0 prob  0.05
# Episode: 204, Total Reward: 19.0 prob  0.05
# Episode: 205, Total Reward: 14.0 prob  0.05
# Episode: 206, Total Reward: 14.0 prob  0.05
# Episode: 207, Total Reward: 22.0 prob  0.05
# Episode: 208, Total Reward: 20.0 prob  0.05
# Episode: 209, Total Reward: 14.0 prob  0.05
# Episode: 210, Total Reward: 19.0 prob  0.05
# Episode: 211, Total Reward: 17.0 prob  0.05
# Episode: 212, Total Reward: 22.0 prob  0.05
# Episode: 213, Total Reward: 25.0 prob  0.05
# Episode: 214, Total Reward: 37.0 prob  0.05
# Episode: 215, Total Reward: 16.0 prob  0.05
# Episode: 216, Total Reward: 23.0 prob  0.05
# Episode: 217, Total Reward: 22.0 prob  0.05
# Episode: 218, Total Reward: 19.0 prob  0.05
# Episode: 219, Total Reward: 16.0 prob  0.05
# Episode: 220, Total Reward: 28.0 prob  0.05
# Episode: 221, Total Reward: 25.0 prob  0.05
# Episode: 222, Total Reward: 15.0 prob  0.05
# Episode: 223, Total Reward: 30.0 prob  0.05
# Episode: 224, Total Reward: 16.0 prob  0.05
# Episode: 225, Total Reward: 28.0 prob  0.05
# Episode: 226, Total Reward: 24.0 prob  0.05
# Episode: 227, Total Reward: 18.0 prob  0.05
# Episode: 228, Total Reward: 28.0 prob  0.05
# Episode: 229, Total Reward: 26.0 prob  0.05
# Episode: 230, Total Reward: 48.0 prob  0.05
# Episode: 231, Total Reward: 30.0 prob  0.05
# Episode: 232, Total Reward: 41.0 prob  0.05
# save_model 70.0
# Episode: 233, Total Reward: 70.0 prob  0.05
# Episode: 234, Total Reward: 28.0 prob  0.05
# Episode: 235, Total Reward: 20.0 prob  0.05
# Episode: 236, Total Reward: 60.0 prob  0.05
# Episode: 237, Total Reward: 22.0 prob  0.05
# Episode: 238, Total Reward: 21.0 prob  0.05
# Episode: 239, Total Reward: 21.0 prob  0.05
# Episode: 240, Total Reward: 17.0 prob  0.05
# Episode: 241, Total Reward: 21.0 prob  0.05
# Episode: 242, Total Reward: 31.0 prob  0.05
# Episode: 243, Total Reward: 26.0 prob  0.05
# Episode: 244, Total Reward: 26.0 prob  0.05
# Episode: 245, Total Reward: 30.0 prob  0.05
# Episode: 246, Total Reward: 23.0 prob  0.05
# Episode: 247, Total Reward: 29.0 prob  0.05
# Episode: 248, Total Reward: 22.0 prob  0.05
# Episode: 249, Total Reward: 42.0 prob  0.05
# Episode: 250, Total Reward: 31.0 prob  0.05
# Episode: 251, Total Reward: 35.0 prob  0.05
# Episode: 252, Total Reward: 37.0 prob  0.05
# Episode: 253, Total Reward: 20.0 prob  0.05
# Episode: 254, Total Reward: 46.0 prob  0.05
# Episode: 255, Total Reward: 19.0 prob  0.05
# Episode: 256, Total Reward: 28.0 prob  0.05
# Episode: 257, Total Reward: 47.0 prob  0.05
# Episode: 258, Total Reward: 51.0 prob  0.05
# Episode: 259, Total Reward: 35.0 prob  0.05
# Episode: 260, Total Reward: 23.0 prob  0.05
# Episode: 261, Total Reward: 21.0 prob  0.05
# Episode: 262, Total Reward: 31.0 prob  0.05
# Episode: 263, Total Reward: 18.0 prob  0.05
# Episode: 264, Total Reward: 32.0 prob  0.05
# Episode: 265, Total Reward: 32.0 prob  0.05
# Episode: 266, Total Reward: 24.0 prob  0.05
# Episode: 267, Total Reward: 33.0 prob  0.05
# Episode: 268, Total Reward: 25.0 prob  0.05
# Episode: 269, Total Reward: 44.0 prob  0.05
# Episode: 270, Total Reward: 37.0 prob  0.05
# Episode: 271, Total Reward: 27.0 prob  0.05
# Episode: 272, Total Reward: 64.0 prob  0.05
# Episode: 273, Total Reward: 43.0 prob  0.05
# Episode: 274, Total Reward: 49.0 prob  0.05
# Episode: 275, Total Reward: 63.0 prob  0.05
# Episode: 276, Total Reward: 40.0 prob  0.05
# Episode: 277, Total Reward: 38.0 prob  0.05
# Episode: 278, Total Reward: 42.0 prob  0.05
# Episode: 279, Total Reward: 59.0 prob  0.05
# Episode: 280, Total Reward: 34.0 prob  0.05
# save_model 70.0
# Episode: 281, Total Reward: 70.0 prob  0.05
# Episode: 282, Total Reward: 35.0 prob  0.05
# save_model 72.0
# Episode: 283, Total Reward: 72.0 prob  0.05
# Episode: 284, Total Reward: 42.0 prob  0.05
# save_model 101.0
# Episode: 285, Total Reward: 101.0 prob  0.05
# Episode: 286, Total Reward: 59.0 prob  0.05
# Episode: 287, Total Reward: 74.0 prob  0.05
# Episode: 288, Total Reward: 62.0 prob  0.05
# Episode: 289, Total Reward: 78.0 prob  0.05
# Episode: 290, Total Reward: 56.0 prob  0.05
# Episode: 291, Total Reward: 35.0 prob  0.05
# Episode: 292, Total Reward: 41.0 prob  0.05
# Episode: 293, Total Reward: 39.0 prob  0.05
# Episode: 294, Total Reward: 48.0 prob  0.05
# Episode: 295, Total Reward: 40.0 prob  0.05
# Episode: 296, Total Reward: 31.0 prob  0.05
# Episode: 297, Total Reward: 66.0 prob  0.05
# Episode: 298, Total Reward: 70.0 prob  0.05
# Episode: 299, Total Reward: 60.0 prob  0.05
# Episode: 300, Total Reward: 64.0 prob  0.05
# Episode: 301, Total Reward: 49.0 prob  0.05
# Episode: 302, Total Reward: 47.0 prob  0.05
# Episode: 303, Total Reward: 60.0 prob  0.05
# Episode: 304, Total Reward: 54.0 prob  0.05
# Episode: 305, Total Reward: 59.0 prob  0.05
# Episode: 306, Total Reward: 70.0 prob  0.05
# Episode: 307, Total Reward: 83.0 prob  0.05
# Episode: 308, Total Reward: 47.0 prob  0.05
# Episode: 309, Total Reward: 73.0 prob  0.05
# Episode: 310, Total Reward: 54.0 prob  0.05
# Episode: 311, Total Reward: 51.0 prob  0.05
# save_model 188.0
# Episode: 312, Total Reward: 188.0 prob  0.05
# Episode: 313, Total Reward: 76.0 prob  0.05
# Episode: 314, Total Reward: 145.0 prob  0.05
# Episode: 315, Total Reward: 121.0 prob  0.05
# Episode: 316, Total Reward: 71.0 prob  0.05
# Episode: 317, Total Reward: 75.0 prob  0.05
# Episode: 318, Total Reward: 102.0 prob  0.05
# Episode: 319, Total Reward: 67.0 prob  0.05
# Episode: 320, Total Reward: 56.0 prob  0.05
# Episode: 321, Total Reward: 87.0 prob  0.05
# Episode: 322, Total Reward: 69.0 prob  0.05
# Episode: 323, Total Reward: 59.0 prob  0.05
# Episode: 324, Total Reward: 94.0 prob  0.05
# Episode: 325, Total Reward: 134.0 prob  0.05
# Episode: 326, Total Reward: 177.0 prob  0.05
# save_model 191.0
# Episode: 327, Total Reward: 191.0 prob  0.05
# Episode: 328, Total Reward: 179.0 prob  0.05
# save_model 267.0
# Episode: 329, Total Reward: 267.0 prob  0.05
# Episode: 330, Total Reward: 154.0 prob  0.05
# Episode: 331, Total Reward: 235.0 prob  0.05
# Episode: 332, Total Reward: 139.0 prob  0.05
# Episode: 333, Total Reward: 186.0 prob  0.05
# save_model 439.0
# Episode: 334, Total Reward: 439.0 prob  0.05
# Episode: 335, Total Reward: 232.0 prob  0.05
# Episode: 336, Total Reward: 227.0 prob  0.05
# Episode: 337, Total Reward: 345.0 prob  0.05
# Episode: 338, Total Reward: 400.0 prob  0.05
# save_model 471.0
# Episode: 339, Total Reward: 471.0 prob  0.05
# Episode: 340, Total Reward: 300.0 prob  0.05
# Episode: 341, Total Reward: 209.0 prob  0.05
# Episode: 342, Total Reward: 145.0 prob  0.05
# Episode: 343, Total Reward: 197.0 prob  0.05
# Episode: 344, Total Reward: 151.0 prob  0.05
# Episode: 345, Total Reward: 152.0 prob  0.05
# Episode: 346, Total Reward: 148.0 prob  0.05
# Episode: 347, Total Reward: 62.0 prob  0.05
# Episode: 348, Total Reward: 105.0 prob  0.05
# Episode: 349, Total Reward: 12.0 prob  0.05
# Episode: 350, Total Reward: 8.0 prob  0.05
# Episode: 351, Total Reward: 11.0 prob  0.05
# Episode: 352, Total Reward: 9.0 prob  0.05
# Episode: 353, Total Reward: 9.0 prob  0.05
# Episode: 354, Total Reward: 10.0 prob  0.05
# Episode: 355, Total Reward: 14.0 prob  0.05
# Episode: 356, Total Reward: 11.0 prob  0.05
# Episode: 357, Total Reward: 9.0 prob  0.05
# Episode: 358, Total Reward: 10.0 prob  0.05
# Episode: 359, Total Reward: 8.0 prob  0.05
# Episode: 360, Total Reward: 11.0 prob  0.05
# Episode: 361, Total Reward: 9.0 prob  0.05
# Episode: 362, Total Reward: 11.0 prob  0.05
# Episode: 363, Total Reward: 9.0 prob  0.05
# Episode: 364, Total Reward: 10.0 prob  0.05
# Episode: 365, Total Reward: 10.0 prob  0.05
# Episode: 366, Total Reward: 10.0 prob  0.05
# Episode: 367, Total Reward: 10.0 prob  0.05
# Episode: 368, Total Reward: 10.0 prob  0.05
# Episode: 369, Total Reward: 10.0 prob  0.05
# Episode: 370, Total Reward: 10.0 prob  0.05
# Episode: 371, Total Reward: 9.0 prob  0.05
# Episode: 372, Total Reward: 9.0 prob  0.05
# Episode: 373, Total Reward: 9.0 prob  0.05
# Episode: 374, Total Reward: 8.0 prob  0.05
# Episode: 375, Total Reward: 9.0 prob  0.05
# Episode: 376, Total Reward: 10.0 prob  0.05
# Episode: 377, Total Reward: 9.0 prob  0.05
# Episode: 378, Total Reward: 9.0 prob  0.05
# Episode: 379, Total Reward: 11.0 prob  0.05
# Episode: 380, Total Reward: 12.0 prob  0.05
# Episode: 381, Total Reward: 9.0 prob  0.05
# Episode: 382, Total Reward: 9.0 prob  0.05
# Episode: 383, Total Reward: 11.0 prob  0.05
# Episode: 384, Total Reward: 9.0 prob  0.05
# Episode: 385, Total Reward: 11.0 prob  0.05
# Episode: 386, Total Reward: 9.0 prob  0.05
# Episode: 387, Total Reward: 11.0 prob  0.05
# Episode: 388, Total Reward: 10.0 prob  0.05
# Episode: 389, Total Reward: 16.0 prob  0.05
# Episode: 390, Total Reward: 13.0 prob  0.05
# Episode: 391, Total Reward: 11.0 prob  0.05
# Episode: 392, Total Reward: 10.0 prob  0.05
# Episode: 393, Total Reward: 10.0 prob  0.05
# Episode: 394, Total Reward: 10.0 prob  0.05
# Episode: 395, Total Reward: 9.0 prob  0.05
# Episode: 396, Total Reward: 10.0 prob  0.05
# Episode: 397, Total Reward: 9.0 prob  0.05
# Episode: 398, Total Reward: 10.0 prob  0.05
# Episode: 399, Total Reward: 8.0 prob  0.05
# Episode: 400, Total Reward: 9.0 prob  0.05
# Episode: 401, Total Reward: 9.0 prob  0.05
# Episode: 402, Total Reward: 9.0 prob  0.05
# Episode: 403, Total Reward: 10.0 prob  0.05
# Episode: 404, Total Reward: 9.0 prob  0.05
# Episode: 405, Total Reward: 10.0 prob  0.05
# Episode: 406, Total Reward: 9.0 prob  0.05
# Episode: 407, Total Reward: 9.0 prob  0.05
# Episode: 408, Total Reward: 9.0 prob  0.05
# Episode: 409, Total Reward: 11.0 prob  0.05
# Episode: 410, Total Reward: 8.0 prob  0.05
# Episode: 411, Total Reward: 13.0 prob  0.05
# Episode: 412, Total Reward: 10.0 prob  0.05
# Episode: 413, Total Reward: 9.0 prob  0.05
# Episode: 414, Total Reward: 10.0 prob  0.05
# Episode: 415, Total Reward: 10.0 prob  0.05
# Episode: 416, Total Reward: 9.0 prob  0.05
# Episode: 417, Total Reward: 9.0 prob  0.05
# Episode: 418, Total Reward: 11.0 prob  0.05
# Episode: 419, Total Reward: 9.0 prob  0.05
# Episode: 420, Total Reward: 9.0 prob  0.05
# Episode: 421, Total Reward: 8.0 prob  0.05
# Episode: 422, Total Reward: 10.0 prob  0.05
# Episode: 423, Total Reward: 10.0 prob  0.05
# Episode: 424, Total Reward: 19.0 prob  0.05
# Episode: 425, Total Reward: 14.0 prob  0.05
# Episode: 426, Total Reward: 10.0 prob  0.05
# Episode: 427, Total Reward: 9.0 prob  0.05
# Episode: 428, Total Reward: 9.0 prob  0.05
# Episode: 429, Total Reward: 10.0 prob  0.05
# Episode: 430, Total Reward: 10.0 prob  0.05
# Episode: 431, Total Reward: 10.0 prob  0.05
# Episode: 432, Total Reward: 20.0 prob  0.05
# Episode: 433, Total Reward: 11.0 prob  0.05
# Episode: 434, Total Reward: 9.0 prob  0.05
# Episode: 435, Total Reward: 9.0 prob  0.05
# Episode: 436, Total Reward: 9.0 prob  0.05
# Episode: 437, Total Reward: 9.0 prob  0.05
# Episode: 438, Total Reward: 10.0 prob  0.05
# Episode: 439, Total Reward: 10.0 prob  0.05
# Episode: 440, Total Reward: 10.0 prob  0.05
# Episode: 441, Total Reward: 9.0 prob  0.05
# Episode: 442, Total Reward: 10.0 prob  0.05
# Episode: 443, Total Reward: 10.0 prob  0.05
# Episode: 444, Total Reward: 10.0 prob  0.05
# Episode: 445, Total Reward: 9.0 prob  0.05
# Episode: 446, Total Reward: 9.0 prob  0.05
# Episode: 447, Total Reward: 11.0 prob  0.05
# Episode: 448, Total Reward: 10.0 prob  0.05
# Episode: 449, Total Reward: 10.0 prob  0.05
# Episode: 450, Total Reward: 10.0 prob  0.05
# Episode: 451, Total Reward: 12.0 prob  0.05
# Episode: 452, Total Reward: 10.0 prob  0.05
# Episode: 453, Total Reward: 8.0 prob  0.05
# Episode: 454, Total Reward: 9.0 prob  0.05
# Episode: 455, Total Reward: 9.0 prob  0.05
# Episode: 456, Total Reward: 8.0 prob  0.05
# Episode: 457, Total Reward: 9.0 prob  0.05
# Episode: 458, Total Reward: 10.0 prob  0.05
# Episode: 459, Total Reward: 10.0 prob  0.05
# Episode: 460, Total Reward: 8.0 prob  0.05
# Episode: 461, Total Reward: 9.0 prob  0.05
# Episode: 462, Total Reward: 10.0 prob  0.05
# Episode: 463, Total Reward: 10.0 prob  0.05
# Episode: 464, Total Reward: 11.0 prob  0.05
# Episode: 465, Total Reward: 10.0 prob  0.05
# Episode: 466, Total Reward: 9.0 prob  0.05
# Episode: 467, Total Reward: 10.0 prob  0.05
# Episode: 468, Total Reward: 12.0 prob  0.05
# Episode: 469, Total Reward: 11.0 prob  0.05
# Episode: 470, Total Reward: 9.0 prob  0.05
# Episode: 471, Total Reward: 8.0 prob  0.05
# Episode: 472, Total Reward: 10.0 prob  0.05
# Episode: 473, Total Reward: 10.0 prob  0.05
# Episode: 474, Total Reward: 9.0 prob  0.05
# Episode: 475, Total Reward: 8.0 prob  0.05
# Episode: 476, Total Reward: 9.0 prob  0.05
# Episode: 477, Total Reward: 10.0 prob  0.05
# Episode: 478, Total Reward: 10.0 prob  0.05
# Episode: 479, Total Reward: 9.0 prob  0.05
# Episode: 480, Total Reward: 9.0 prob  0.05
# Episode: 481, Total Reward: 9.0 prob  0.05
# Episode: 482, Total Reward: 10.0 prob  0.05
# Episode: 483, Total Reward: 10.0 prob  0.05
# Episode: 484, Total Reward: 9.0 prob  0.05
# Episode: 485, Total Reward: 9.0 prob  0.05
# Episode: 486, Total Reward: 9.0 prob  0.05
# Episode: 487, Total Reward: 10.0 prob  0.05
# Episode: 488, Total Reward: 8.0 prob  0.05
# Episode: 489, Total Reward: 10.0 prob  0.05
# Episode: 490, Total Reward: 9.0 prob  0.05
# Episode: 491, Total Reward: 9.0 prob  0.05
# Episode: 492, Total Reward: 10.0 prob  0.05
# Episode: 493, Total Reward: 30.0 prob  0.05
# Episode: 494, Total Reward: 10.0 prob  0.05
# Episode: 495, Total Reward: 9.0 prob  0.05
# Episode: 496, Total Reward: 10.0 prob  0.05
# Episode: 497, Total Reward: 9.0 prob  0.05
# Episode: 498, Total Reward: 8.0 prob  0.05
# Episode: 499, Total Reward: 10.0 prob  0.05
# Episode: 500, Total Reward: 9.0 prob  0.05
# Episode: 501, Total Reward: 9.0 prob  0.05
# Episode: 502, Total Reward: 9.0 prob  0.05
# Episode: 503, Total Reward: 8.0 prob  0.05
# Episode: 504, Total Reward: 9.0 prob  0.05
# Episode: 505, Total Reward: 9.0 prob  0.05
# Episode: 506, Total Reward: 10.0 prob  0.05
# Episode: 507, Total Reward: 9.0 prob  0.05
# Episode: 508, Total Reward: 10.0 prob  0.05
# Episode: 509, Total Reward: 9.0 prob  0.05
# Episode: 510, Total Reward: 10.0 prob  0.05
# Episode: 511, Total Reward: 9.0 prob  0.05
# Episode: 512, Total Reward: 9.0 prob  0.05
# Episode: 513, Total Reward: 10.0 prob  0.05
# Episode: 514, Total Reward: 9.0 prob  0.05
# Episode: 515, Total Reward: 9.0 prob  0.05
# Episode: 516, Total Reward: 9.0 prob  0.05
# Episode: 517, Total Reward: 8.0 prob  0.05
# Episode: 518, Total Reward: 8.0 prob  0.05
# Episode: 519, Total Reward: 10.0 prob  0.05
# Episode: 520, Total Reward: 8.0 prob  0.05
# Episode: 521, Total Reward: 10.0 prob  0.05
# Episode: 522, Total Reward: 10.0 prob  0.05
# Episode: 523, Total Reward: 9.0 prob  0.05
# Episode: 524, Total Reward: 10.0 prob  0.05
# Episode: 525, Total Reward: 9.0 prob  0.05
# Episode: 526, Total Reward: 10.0 prob  0.05
# Episode: 527, Total Reward: 11.0 prob  0.05
# Episode: 528, Total Reward: 10.0 prob  0.05
# Episode: 529, Total Reward: 10.0 prob  0.05
# Episode: 530, Total Reward: 9.0 prob  0.05
# Episode: 531, Total Reward: 9.0 prob  0.05
# Episode: 532, Total Reward: 9.0 prob  0.05
# Episode: 533, Total Reward: 10.0 prob  0.05
# Episode: 534, Total Reward: 9.0 prob  0.05
# Episode: 535, Total Reward: 9.0 prob  0.05
# Episode: 536, Total Reward: 9.0 prob  0.05
# Episode: 537, Total Reward: 10.0 prob  0.05
# Episode: 538, Total Reward: 10.0 prob  0.05
# Episode: 539, Total Reward: 10.0 prob  0.05
# Episode: 540, Total Reward: 9.0 prob  0.05
# Episode: 541, Total Reward: 9.0 prob  0.05
# Episode: 542, Total Reward: 11.0 prob  0.05
# Episode: 543, Total Reward: 8.0 prob  0.05
# Episode: 544, Total Reward: 9.0 prob  0.05
# Episode: 545, Total Reward: 8.0 prob  0.05
# Episode: 546, Total Reward: 10.0 prob  0.05
# Episode: 547, Total Reward: 9.0 prob  0.05
# Episode: 548, Total Reward: 12.0 prob  0.05
# Episode: 549, Total Reward: 10.0 prob  0.05
# Episode: 550, Total Reward: 9.0 prob  0.05
# Episode: 551, Total Reward: 8.0 prob  0.05
# Episode: 552, Total Reward: 13.0 prob  0.05
# Episode: 553, Total Reward: 10.0 prob  0.05
# Episode: 554, Total Reward: 8.0 prob  0.05
# Episode: 555, Total Reward: 11.0 prob  0.05
# Episode: 556, Total Reward: 10.0 prob  0.05
# Episode: 557, Total Reward: 9.0 prob  0.05
# Episode: 558, Total Reward: 10.0 prob  0.05
# Episode: 559, Total Reward: 9.0 prob  0.05
# Episode: 560, Total Reward: 9.0 prob  0.05
# Episode: 561, Total Reward: 8.0 prob  0.05
# Episode: 562, Total Reward: 9.0 prob  0.05
# Episode: 563, Total Reward: 11.0 prob  0.05
# Episode: 564, Total Reward: 10.0 prob  0.05
# Episode: 565, Total Reward: 11.0 prob  0.05
# Episode: 566, Total Reward: 9.0 prob  0.05
# Episode: 567, Total Reward: 10.0 prob  0.05
# Episode: 568, Total Reward: 9.0 prob  0.05
# Episode: 569, Total Reward: 10.0 prob  0.05
# Episode: 570, Total Reward: 10.0 prob  0.05
# Episode: 571, Total Reward: 11.0 prob  0.05
# Episode: 572, Total Reward: 9.0 prob  0.05
# Episode: 573, Total Reward: 8.0 prob  0.05
# Episode: 574, Total Reward: 10.0 prob  0.05
# Episode: 575, Total Reward: 11.0 prob  0.05
# Episode: 576, Total Reward: 10.0 prob  0.05
# Episode: 577, Total Reward: 10.0 prob  0.05
# Episode: 578, Total Reward: 9.0 prob  0.05
# Episode: 579, Total Reward: 9.0 prob  0.05
# Episode: 580, Total Reward: 10.0 prob  0.05
# Episode: 581, Total Reward: 9.0 prob  0.05
# Episode: 582, Total Reward: 8.0 prob  0.05
# Episode: 583, Total Reward: 10.0 prob  0.05
# Episode: 584, Total Reward: 10.0 prob  0.05
# Episode: 585, Total Reward: 12.0 prob  0.05
# Episode: 586, Total Reward: 11.0 prob  0.05
# Episode: 587, Total Reward: 9.0 prob  0.05
# Episode: 588, Total Reward: 8.0 prob  0.05
# Episode: 589, Total Reward: 11.0 prob  0.05
# Episode: 590, Total Reward: 10.0 prob  0.05
# Episode: 591, Total Reward: 10.0 prob  0.05
# Episode: 592, Total Reward: 10.0 prob  0.05
# Episode: 593, Total Reward: 8.0 prob  0.05
# Episode: 594, Total Reward: 11.0 prob  0.05
# Episode: 595, Total Reward: 9.0 prob  0.05
# Episode: 596, Total Reward: 11.0 prob  0.05
# Episode: 597, Total Reward: 10.0 prob  0.05
# Episode: 598, Total Reward: 9.0 prob  0.05
# Episode: 599, Total Reward: 11.0 prob  0.05
# Episode: 600, Total Reward: 10.0 prob  0.05
# Episode: 601, Total Reward: 10.0 prob  0.05
# Episode: 602, Total Reward: 8.0 prob  0.05
# Episode: 603, Total Reward: 9.0 prob  0.05
# Episode: 604, Total Reward: 10.0 prob  0.05
# Episode: 605, Total Reward: 10.0 prob  0.05
# Episode: 606, Total Reward: 9.0 prob  0.05
# Episode: 607, Total Reward: 9.0 prob  0.05
# Episode: 608, Total Reward: 10.0 prob  0.05
# Episode: 609, Total Reward: 10.0 prob  0.05
# Episode: 610, Total Reward: 9.0 prob  0.05
# Episode: 611, Total Reward: 8.0 prob  0.05
# Episode: 612, Total Reward: 9.0 prob  0.05
# Episode: 613, Total Reward: 9.0 prob  0.05
# Episode: 614, Total Reward: 10.0 prob  0.05
# Episode: 615, Total Reward: 11.0 prob  0.05
# Episode: 616, Total Reward: 10.0 prob  0.05
# Episode: 617, Total Reward: 10.0 prob  0.05
# Episode: 618, Total Reward: 12.0 prob  0.05
# Episode: 619, Total Reward: 11.0 prob  0.05
# Episode: 620, Total Reward: 9.0 prob  0.05
# Episode: 621, Total Reward: 9.0 prob  0.05
# Episode: 622, Total Reward: 9.0 prob  0.05
# Episode: 623, Total Reward: 10.0 prob  0.05
# Episode: 624, Total Reward: 10.0 prob  0.05
# Episode: 625, Total Reward: 10.0 prob  0.05
# Episode: 626, Total Reward: 10.0 prob  0.05
# Episode: 627, Total Reward: 10.0 prob  0.05
# Episode: 628, Total Reward: 10.0 prob  0.05
# Episode: 629, Total Reward: 10.0 prob  0.05
# Episode: 630, Total Reward: 10.0 prob  0.05
# Episode: 631, Total Reward: 9.0 prob  0.05
# Episode: 632, Total Reward: 10.0 prob  0.05
# Episode: 633, Total Reward: 10.0 prob  0.05
# Episode: 634, Total Reward: 12.0 prob  0.05
# Episode: 635, Total Reward: 9.0 prob  0.05
# Episode: 636, Total Reward: 12.0 prob  0.05
# Episode: 637, Total Reward: 9.0 prob  0.05
# Episode: 638, Total Reward: 11.0 prob  0.05
# Episode: 639, Total Reward: 9.0 prob  0.05
# Episode: 640, Total Reward: 9.0 prob  0.05
# Episode: 641, Total Reward: 9.0 prob  0.05
# Episode: 642, Total Reward: 9.0 prob  0.05
# Episode: 643, Total Reward: 10.0 prob  0.05
# Episode: 644, Total Reward: 10.0 prob  0.05
# Episode: 645, Total Reward: 10.0 prob  0.05
# Episode: 646, Total Reward: 10.0 prob  0.05
# Episode: 647, Total Reward: 11.0 prob  0.05
# Episode: 648, Total Reward: 9.0 prob  0.05
# Episode: 649, Total Reward: 10.0 prob  0.05
# Episode: 650, Total Reward: 11.0 prob  0.05
# Episode: 651, Total Reward: 10.0 prob  0.05
# Episode: 652, Total Reward: 10.0 prob  0.05
# Episode: 653, Total Reward: 9.0 prob  0.05
# Episode: 654, Total Reward: 9.0 prob  0.05
# Episode: 655, Total Reward: 9.0 prob  0.05
# Episode: 656, Total Reward: 9.0 prob  0.05
# Episode: 657, Total Reward: 9.0 prob  0.05
# Episode: 658, Total Reward: 9.0 prob  0.05
# Episode: 659, Total Reward: 9.0 prob  0.05
# Episode: 660, Total Reward: 9.0 prob  0.05
# Episode: 661, Total Reward: 10.0 prob  0.05
# Episode: 662, Total Reward: 10.0 prob  0.05
# Episode: 663, Total Reward: 11.0 prob  0.05
# Episode: 664, Total Reward: 12.0 prob  0.05
# Episode: 665, Total Reward: 10.0 prob  0.05
# Episode: 666, Total Reward: 10.0 prob  0.05
# Episode: 667, Total Reward: 10.0 prob  0.05
# Episode: 668, Total Reward: 10.0 prob  0.05
# Episode: 669, Total Reward: 9.0 prob  0.05
# Episode: 670, Total Reward: 9.0 prob  0.05
# Episode: 671, Total Reward: 10.0 prob  0.05
# Episode: 672, Total Reward: 10.0 prob  0.05
# Episode: 673, Total Reward: 10.0 prob  0.05
# Episode: 674, Total Reward: 10.0 prob  0.05
# Episode: 675, Total Reward: 8.0 prob  0.05
# Episode: 676, Total Reward: 11.0 prob  0.05
# Episode: 677, Total Reward: 9.0 prob  0.05
# Episode: 678, Total Reward: 10.0 prob  0.05
# Episode: 679, Total Reward: 9.0 prob  0.05
# Episode: 680, Total Reward: 9.0 prob  0.05
# Episode: 681, Total Reward: 9.0 prob  0.05
# Episode: 682, Total Reward: 9.0 prob  0.05
# Episode: 683, Total Reward: 11.0 prob  0.05
# Episode: 684, Total Reward: 9.0 prob  0.05
# Episode: 685, Total Reward: 10.0 prob  0.05
# Episode: 686, Total Reward: 10.0 prob  0.05
# Episode: 687, Total Reward: 8.0 prob  0.05
# Episode: 688, Total Reward: 10.0 prob  0.05
# Episode: 689, Total Reward: 9.0 prob  0.05
# Episode: 690, Total Reward: 10.0 prob  0.05
# Episode: 691, Total Reward: 9.0 prob  0.05
# Episode: 692, Total Reward: 10.0 prob  0.05
# Episode: 693, Total Reward: 9.0 prob  0.05
# Episode: 694, Total Reward: 10.0 prob  0.05
# Episode: 695, Total Reward: 10.0 prob  0.05
# Episode: 696, Total Reward: 10.0 prob  0.05
# Episode: 697, Total Reward: 10.0 prob  0.05
# Episode: 698, Total Reward: 10.0 prob  0.05
# Episode: 699, Total Reward: 10.0 prob  0.05
# Episode: 700, Total Reward: 12.0 prob  0.05
# Episode: 701, Total Reward: 9.0 prob  0.05
# Episode: 702, Total Reward: 8.0 prob  0.05
# Episode: 703, Total Reward: 10.0 prob  0.05
# Episode: 704, Total Reward: 8.0 prob  0.05
# Episode: 705, Total Reward: 10.0 prob  0.05
# Episode: 706, Total Reward: 9.0 prob  0.05
# Episode: 707, Total Reward: 10.0 prob  0.05
# Episode: 708, Total Reward: 10.0 prob  0.05
# Episode: 709, Total Reward: 9.0 prob  0.05
# Episode: 710, Total Reward: 10.0 prob  0.05
# Episode: 711, Total Reward: 11.0 prob  0.05
# Episode: 712, Total Reward: 10.0 prob  0.05
# Episode: 713, Total Reward: 9.0 prob  0.05
# Episode: 714, Total Reward: 11.0 prob  0.05
# Episode: 715, Total Reward: 10.0 prob  0.05
# Episode: 716, Total Reward: 10.0 prob  0.05
# Episode: 717, Total Reward: 10.0 prob  0.05
# Episode: 718, Total Reward: 10.0 prob  0.05
# Episode: 719, Total Reward: 9.0 prob  0.05
# Episode: 720, Total Reward: 9.0 prob  0.05
# Episode: 721, Total Reward: 9.0 prob  0.05
# Episode: 722, Total Reward: 10.0 prob  0.05
# Episode: 723, Total Reward: 10.0 prob  0.05
# Episode: 724, Total Reward: 9.0 prob  0.05
# Episode: 725, Total Reward: 9.0 prob  0.05
# Episode: 726, Total Reward: 11.0 prob  0.05
# Episode: 727, Total Reward: 10.0 prob  0.05
# Episode: 728, Total Reward: 10.0 prob  0.05
# Episode: 729, Total Reward: 11.0 prob  0.05
# Episode: 730, Total Reward: 9.0 prob  0.05
# Episode: 731, Total Reward: 9.0 prob  0.05
# Episode: 732, Total Reward: 8.0 prob  0.05
# Episode: 733, Total Reward: 10.0 prob  0.05
# Episode: 734, Total Reward: 9.0 prob  0.05
# Episode: 735, Total Reward: 10.0 prob  0.05
# Episode: 736, Total Reward: 13.0 prob  0.05
# Episode: 737, Total Reward: 9.0 prob  0.05
# Episode: 738, Total Reward: 10.0 prob  0.05
# Episode: 739, Total Reward: 10.0 prob  0.05
# Episode: 740, Total Reward: 10.0 prob  0.05
# Episode: 741, Total Reward: 10.0 prob  0.05
# Episode: 742, Total Reward: 10.0 prob  0.05
# Episode: 743, Total Reward: 8.0 prob  0.05
# Episode: 744, Total Reward: 10.0 prob  0.05
# Episode: 745, Total Reward: 10.0 prob  0.05
# Episode: 746, Total Reward: 10.0 prob  0.05
# Episode: 747, Total Reward: 10.0 prob  0.05
# Episode: 748, Total Reward: 10.0 prob  0.05
# Episode: 749, Total Reward: 9.0 prob  0.05
# Episode: 750, Total Reward: 10.0 prob  0.05
# Episode: 751, Total Reward: 10.0 prob  0.05
# Episode: 752, Total Reward: 9.0 prob  0.05
# Episode: 753, Total Reward: 17.0 prob  0.05
# Episode: 754, Total Reward: 9.0 prob  0.05
# Episode: 755, Total Reward: 10.0 prob  0.05
# Episode: 756, Total Reward: 9.0 prob  0.05
# Episode: 757, Total Reward: 8.0 prob  0.05
# Episode: 758, Total Reward: 8.0 prob  0.05
# Episode: 759, Total Reward: 9.0 prob  0.05
# Episode: 760, Total Reward: 8.0 prob  0.05
# Episode: 761, Total Reward: 9.0 prob  0.05
# Episode: 762, Total Reward: 9.0 prob  0.05
# Episode: 763, Total Reward: 9.0 prob  0.05
# Episode: 764, Total Reward: 9.0 prob  0.05
# Episode: 765, Total Reward: 9.0 prob  0.05
# Episode: 766, Total Reward: 10.0 prob  0.05
# Episode: 767, Total Reward: 12.0 prob  0.05
# Episode: 768, Total Reward: 9.0 prob  0.05
# Episode: 769, Total Reward: 9.0 prob  0.05
# Episode: 770, Total Reward: 9.0 prob  0.05
# Episode: 771, Total Reward: 8.0 prob  0.05
# Episode: 772, Total Reward: 10.0 prob  0.05
# Episode: 773, Total Reward: 9.0 prob  0.05
# Episode: 774, Total Reward: 10.0 prob  0.05
# Episode: 775, Total Reward: 10.0 prob  0.05
# Episode: 776, Total Reward: 9.0 prob  0.05
# Episode: 777, Total Reward: 10.0 prob  0.05
# Episode: 778, Total Reward: 10.0 prob  0.05
# Episode: 779, Total Reward: 10.0 prob  0.05
# Episode: 780, Total Reward: 9.0 prob  0.05
# Episode: 781, Total Reward: 9.0 prob  0.05
# Episode: 782, Total Reward: 11.0 prob  0.05
# Episode: 783, Total Reward: 11.0 prob  0.05
# Episode: 784, Total Reward: 8.0 prob  0.05
# Episode: 785, Total Reward: 8.0 prob  0.05
# Episode: 786, Total Reward: 10.0 prob  0.05
# Episode: 787, Total Reward: 9.0 prob  0.05
# Episode: 788, Total Reward: 9.0 prob  0.05
# Episode: 789, Total Reward: 9.0 prob  0.05
# Episode: 790, Total Reward: 9.0 prob  0.05
# Episode: 791, Total Reward: 12.0 prob  0.05
# Episode: 792, Total Reward: 10.0 prob  0.05
# Episode: 793, Total Reward: 13.0 prob  0.05
# Episode: 794, Total Reward: 10.0 prob  0.05
# Episode: 795, Total Reward: 13.0 prob  0.05
# Episode: 796, Total Reward: 9.0 prob  0.05
# Episode: 797, Total Reward: 8.0 prob  0.05
# Episode: 798, Total Reward: 9.0 prob  0.05
# Episode: 799, Total Reward: 8.0 prob  0.05
# Episode: 800, Total Reward: 8.0 prob  0.05
# Episode: 801, Total Reward: 8.0 prob  0.05
# Episode: 802, Total Reward: 10.0 prob  0.05
# Episode: 803, Total Reward: 14.0 prob  0.05
# Episode: 804, Total Reward: 10.0 prob  0.05
# Episode: 805, Total Reward: 9.0 prob  0.05
# Episode: 806, Total Reward: 8.0 prob  0.05
# Episode: 807, Total Reward: 12.0 prob  0.05
# Episode: 808, Total Reward: 10.0 prob  0.05
# Episode: 809, Total Reward: 8.0 prob  0.05
# Episode: 810, Total Reward: 10.0 prob  0.05
# Episode: 811, Total Reward: 8.0 prob  0.05
# Episode: 812, Total Reward: 9.0 prob  0.05
# Episode: 813, Total Reward: 10.0 prob  0.05
# Episode: 814, Total Reward: 10.0 prob  0.05
# Episode: 815, Total Reward: 10.0 prob  0.05
# Episode: 816, Total Reward: 8.0 prob  0.05
# Episode: 817, Total Reward: 10.0 prob  0.05
# Episode: 818, Total Reward: 9.0 prob  0.05
# Episode: 819, Total Reward: 9.0 prob  0.05
# Episode: 820, Total Reward: 10.0 prob  0.05
# Episode: 821, Total Reward: 9.0 prob  0.05
# Episode: 822, Total Reward: 10.0 prob  0.05
# Episode: 823, Total Reward: 8.0 prob  0.05
# Episode: 824, Total Reward: 9.0 prob  0.05
# Episode: 825, Total Reward: 10.0 prob  0.05
# Episode: 826, Total Reward: 9.0 prob  0.05
# Episode: 827, Total Reward: 9.0 prob  0.05
# Episode: 828, Total Reward: 9.0 prob  0.05
# Episode: 829, Total Reward: 10.0 prob  0.05
# Episode: 830, Total Reward: 9.0 prob  0.05
# Episode: 831, Total Reward: 10.0 prob  0.05
# Episode: 832, Total Reward: 9.0 prob  0.05
# Episode: 833, Total Reward: 10.0 prob  0.05
# Episode: 834, Total Reward: 10.0 prob  0.05
# Episode: 835, Total Reward: 10.0 prob  0.05
# Episode: 836, Total Reward: 10.0 prob  0.05
# Episode: 837, Total Reward: 12.0 prob  0.05
# Episode: 838, Total Reward: 8.0 prob  0.05
# Episode: 839, Total Reward: 9.0 prob  0.05
# Episode: 840, Total Reward: 9.0 prob  0.05
# Episode: 841, Total Reward: 9.0 prob  0.05
# Episode: 842, Total Reward: 10.0 prob  0.05
# Episode: 843, Total Reward: 10.0 prob  0.05
# Episode: 844, Total Reward: 9.0 prob  0.05
# Episode: 845, Total Reward: 12.0 prob  0.05
# Episode: 846, Total Reward: 9.0 prob  0.05
# Episode: 847, Total Reward: 9.0 prob  0.05
# Episode: 848, Total Reward: 9.0 prob  0.05
# Episode: 849, Total Reward: 9.0 prob  0.05
# Episode: 850, Total Reward: 10.0 prob  0.05
# Episode: 851, Total Reward: 9.0 prob  0.05
# Episode: 852, Total Reward: 10.0 prob  0.05
# Episode: 853, Total Reward: 10.0 prob  0.05
# Episode: 854, Total Reward: 10.0 prob  0.05
# Episode: 855, Total Reward: 9.0 prob  0.05
# Episode: 856, Total Reward: 10.0 prob  0.05
# Episode: 857, Total Reward: 11.0 prob  0.05
# Episode: 858, Total Reward: 9.0 prob  0.05
# Episode: 859, Total Reward: 9.0 prob  0.05
# Episode: 860, Total Reward: 10.0 prob  0.05
# Episode: 861, Total Reward: 11.0 prob  0.05
# Episode: 862, Total Reward: 9.0 prob  0.05
# Episode: 863, Total Reward: 10.0 prob  0.05
# Episode: 864, Total Reward: 9.0 prob  0.05
# Episode: 865, Total Reward: 9.0 prob  0.05
# Episode: 866, Total Reward: 10.0 prob  0.05
# Episode: 867, Total Reward: 10.0 prob  0.05
# Episode: 868, Total Reward: 10.0 prob  0.05
# Episode: 869, Total Reward: 9.0 prob  0.05
# Episode: 870, Total Reward: 10.0 prob  0.05
# Episode: 871, Total Reward: 10.0 prob  0.05
# Episode: 872, Total Reward: 12.0 prob  0.05
# Episode: 873, Total Reward: 11.0 prob  0.05
# Episode: 874, Total Reward: 10.0 prob  0.05
# Episode: 875, Total Reward: 10.0 prob  0.05
# Episode: 876, Total Reward: 11.0 prob  0.05
# Episode: 877, Total Reward: 9.0 prob  0.05
# Episode: 878, Total Reward: 8.0 prob  0.05
# Episode: 879, Total Reward: 10.0 prob  0.05
# Episode: 880, Total Reward: 10.0 prob  0.05
# Episode: 881, Total Reward: 10.0 prob  0.05
# Episode: 882, Total Reward: 9.0 prob  0.05
# Episode: 883, Total Reward: 12.0 prob  0.05
# Episode: 884, Total Reward: 10.0 prob  0.05
# Episode: 885, Total Reward: 9.0 prob  0.05
# Episode: 886, Total Reward: 10.0 prob  0.05
# Episode: 887, Total Reward: 10.0 prob  0.05
# Episode: 888, Total Reward: 8.0 prob  0.05
# Episode: 889, Total Reward: 11.0 prob  0.05
# Episode: 890, Total Reward: 9.0 prob  0.05
# Episode: 891, Total Reward: 10.0 prob  0.05
# Episode: 892, Total Reward: 10.0 prob  0.05
# Episode: 893, Total Reward: 10.0 prob  0.05
# Episode: 894, Total Reward: 9.0 prob  0.05
# Episode: 895, Total Reward: 10.0 prob  0.05
# Episode: 896, Total Reward: 10.0 prob  0.05
# Episode: 897, Total Reward: 8.0 prob  0.05
# Episode: 898, Total Reward: 8.0 prob  0.05
# Episode: 899, Total Reward: 10.0 prob  0.05
# Episode: 900, Total Reward: 9.0 prob  0.05
# Episode: 901, Total Reward: 10.0 prob  0.05
# Episode: 902, Total Reward: 9.0 prob  0.05
# Episode: 903, Total Reward: 8.0 prob  0.05
# Episode: 904, Total Reward: 11.0 prob  0.05
# Episode: 905, Total Reward: 9.0 prob  0.05
# Episode: 906, Total Reward: 10.0 prob  0.05
# Episode: 907, Total Reward: 11.0 prob  0.05
# Episode: 908, Total Reward: 10.0 prob  0.05
# Episode: 909, Total Reward: 9.0 prob  0.05
# Episode: 910, Total Reward: 9.0 prob  0.05
# Episode: 911, Total Reward: 8.0 prob  0.05
# Episode: 912, Total Reward: 8.0 prob  0.05
# Episode: 913, Total Reward: 9.0 prob  0.05
# Episode: 914, Total Reward: 10.0 prob  0.05
# Episode: 915, Total Reward: 9.0 prob  0.05
# Episode: 916, Total Reward: 9.0 prob  0.05
# Episode: 917, Total Reward: 10.0 prob  0.05
# Episode: 918, Total Reward: 10.0 prob  0.05
# Episode: 919, Total Reward: 10.0 prob  0.05
# Episode: 920, Total Reward: 9.0 prob  0.05
# Episode: 921, Total Reward: 9.0 prob  0.05
# Episode: 922, Total Reward: 12.0 prob  0.05
# Episode: 923, Total Reward: 10.0 prob  0.05
# Episode: 924, Total Reward: 10.0 prob  0.05
# Episode: 925, Total Reward: 10.0 prob  0.05
# Episode: 926, Total Reward: 25.0 prob  0.05
# Episode: 927, Total Reward: 10.0 prob  0.05
# Episode: 928, Total Reward: 10.0 prob  0.05
# Episode: 929, Total Reward: 9.0 prob  0.05
# Episode: 930, Total Reward: 10.0 prob  0.05
# Episode: 931, Total Reward: 10.0 prob  0.05
# Episode: 932, Total Reward: 9.0 prob  0.05
# Episode: 933, Total Reward: 10.0 prob  0.05
# Episode: 934, Total Reward: 10.0 prob  0.05
# Episode: 935, Total Reward: 9.0 prob  0.05
# Episode: 936, Total Reward: 10.0 prob  0.05
# Episode: 937, Total Reward: 8.0 prob  0.05
# Episode: 938, Total Reward: 10.0 prob  0.05
# Episode: 939, Total Reward: 10.0 prob  0.05
# Episode: 940, Total Reward: 9.0 prob  0.05
# Episode: 941, Total Reward: 9.0 prob  0.05
# Episode: 942, Total Reward: 10.0 prob  0.05
# Episode: 943, Total Reward: 10.0 prob  0.05
# Episode: 944, Total Reward: 9.0 prob  0.05
# Episode: 945, Total Reward: 8.0 prob  0.05
# Episode: 946, Total Reward: 9.0 prob  0.05
# Episode: 947, Total Reward: 9.0 prob  0.05
# Episode: 948, Total Reward: 12.0 prob  0.05
# Episode: 949, Total Reward: 9.0 prob  0.05
# Episode: 950, Total Reward: 10.0 prob  0.05
# Episode: 951, Total Reward: 9.0 prob  0.05
# Episode: 952, Total Reward: 10.0 prob  0.05
# Episode: 953, Total Reward: 8.0 prob  0.05
# Episode: 954, Total Reward: 9.0 prob  0.05
# Episode: 955, Total Reward: 10.0 prob  0.05
# Episode: 956, Total Reward: 10.0 prob  0.05
# Episode: 957, Total Reward: 11.0 prob  0.05
# Episode: 958, Total Reward: 10.0 prob  0.05
# Episode: 959, Total Reward: 9.0 prob  0.05
# Episode: 960, Total Reward: 8.0 prob  0.05
# Episode: 961, Total Reward: 9.0 prob  0.05
# Episode: 962, Total Reward: 9.0 prob  0.05
# Episode: 963, Total Reward: 10.0 prob  0.05
# Episode: 964, Total Reward: 10.0 prob  0.05
# Episode: 965, Total Reward: 9.0 prob  0.05
# Episode: 966, Total Reward: 8.0 prob  0.05
# Episode: 967, Total Reward: 9.0 prob  0.05
# Episode: 968, Total Reward: 10.0 prob  0.05
# Episode: 969, Total Reward: 9.0 prob  0.05
# Episode: 970, Total Reward: 10.0 prob  0.05
# Episode: 971, Total Reward: 9.0 prob  0.05
# Episode: 972, Total Reward: 10.0 prob  0.05
# Episode: 973, Total Reward: 10.0 prob  0.05
# Episode: 974, Total Reward: 8.0 prob  0.05
# Episode: 975, Total Reward: 9.0 prob  0.05
# Episode: 976, Total Reward: 9.0 prob  0.05
# Episode: 977, Total Reward: 10.0 prob  0.05
# Episode: 978, Total Reward: 9.0 prob  0.05
# Episode: 979, Total Reward: 9.0 prob  0.05
# Episode: 980, Total Reward: 8.0 prob  0.05
# Episode: 981, Total Reward: 11.0 prob  0.05
# Episode: 982, Total Reward: 9.0 prob  0.05
# Episode: 983, Total Reward: 10.0 prob  0.05
# Episode: 984, Total Reward: 10.0 prob  0.05
# Episode: 985, Total Reward: 8.0 prob  0.05
# Episode: 986, Total Reward: 11.0 prob  0.05
# Episode: 987, Total Reward: 10.0 prob  0.05
# Episode: 988, Total Reward: 10.0 prob  0.05
# Episode: 989, Total Reward: 9.0 prob  0.05
# Episode: 990, Total Reward: 8.0 prob  0.05
# Episode: 991, Total Reward: 8.0 prob  0.05
# Episode: 992, Total Reward: 10.0 prob  0.05
# Episode: 993, Total Reward: 9.0 prob  0.05
# Episode: 994, Total Reward: 9.0 prob  0.05
# Episode: 995, Total Reward: 9.0 prob  0.05
# Episode: 996, Total Reward: 9.0 prob  0.05
# Episode: 997, Total Reward: 9.0 prob  0.05
# Episode: 998, Total Reward: 26.0 prob  0.05
# Episode: 999, Total Reward: 10.0 prob  0.05
# Episode: 1000, Total Reward: 10.0 prob  0.05

# %% [markdown]
# ## Plot the learning curve
# Below we plot the total reward againt the episodes, you can see that the learning is noisy and quite often it completly forgets everything after 300-400 episodes.

# %%
plt.plot(rewards_list)
plt.xlabel('episode')
plt.ylabel('total reward')
plt.show()

# %% [markdown]
# ## Test the learned policy

# %%
env = gym.make("CartPole-v1", render_mode="human")
#env = gym.make("LunarLander-v2", render_mode="human")

state, info = env.reset()
done = False
total_reward = 0

while not done:
    pred = nn_save.forward(unpack_state(state))
    action = np.argmax(pred)  # greedy
    new_state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    total_reward += reward
    state = new_state
env.close()

# %% [markdown]
# ## Exersice 2.5:
#
# 1. What are the similarities between Q-learning and deep Q-learning?
# 2. What are the differences and what implications does these difference have? Are Q-learning and deep Q-learning equally good at the same tasks or are they suited for different problems?
# 3. Are there any difficulties with deep Q-learning?
# 4. What conclusion can you draw from the the learning curve?

# %% [markdown]
# 1- What are the similarities between Q-learning and deep Q-learning?
# * Both Q-learning and Deep Q-learning are trying to learn the best way to act in a given situation to get the most reward.
#
# * They both learn by trying out different actions, seeing what reward they get, and using that to update their knowledge.
#
# * Both methods have a way to balance trying out new actions (exploration) and sticking with what they know works best (exploitation). This is often done using a method called epsilon-greedy.
#
# * Both Q-learning and Deep Q-learning learn from past experiences, not just from what they’re doing right now. This means they can learn the best way to act, no matter what actions they’re currently taking.
#
# * Both methods can handle situations where the results of an action aren’t immediately known. They do this by keeping track of the actions they’ve taken and updating their knowledge when they find out the result.
#
# The main difference is how they keep track of what they’ve learned (the Q-values). Q-learning uses a simple table, while Deep Q-learning uses a neural network, which is ofcoure much harder
#
# 2- What are the differences and what implications does these difference have? Are Q-learning and deep Q-learning equally good at the same tasks or are they suited for different problems?
# | Aspect | Q-Learning | Deep Q-Learning |
# |---|---|---|
# | **How they remember things** | Uses a simple table. Good for small problems with few options. | Uses a neural network. Can handle much bigger problems. |
# | **How much computer power they need** | Simpler and needs less computer power. | Needs more computer power to train a neural network. |
# | **How stable they are** | Stable and will find the best way to act given enough time. | Can be unstable due to complexities of training neural networks. |
# | **How well they learn** | Learns each option separately, can be slow to learn. | Can learn similar options at the same time, faster for big problems. |
#
#
# Q-learning and Deep Q-learning are not equally good at the same tasks, they are better suited for different types of problems:
#
# * Q-learning is simpler and works well when there are only a few options to remember. It doesn't need much computer power. But if there are lots of options, Q-learning can be slow to learn because it learns each option separately.
#
# * Deep Q-learning on the other hand, is better for big problems with lots of options. Even though it's more complex and needs more computer power, it can learn faster because it can learn similar options at the same time.
#
#
# 3)- Are there any difficulties with deep Q-learning?
#
# Balancing exploration and exploitation. Too much exploration can lead to suboptimal performance, while too much exploitation can prevent the agent from discovering better policies. In this code, this trade-off is managed using the epsilon-greedy strategy, but choosing the right value for epsilon can be tricky.Balancing exploration and exploitation is a key challenge in reinforcement learning. Too much exploration can lead to suboptimal performance, while too much exploitation can prevent the agent from discovering better policies. In our code, this trade-off is managed using the epsilon-greedy strategy, but choosing the right value for epsilon can be tricky.
#
#
# 4)- What conclusion can you draw from the the learning curve?
# It is highly important to highlight that each time we run the learning process we get a slightly different curve with different values. Knowing that :
#
# The sharp increase in total reward around episode 400 suggests that the algorithm has started to learn effective policies from its interactions with the environment. This is likely due to the exploration phase, where the algorithm is trying out different actions and learning from the resulting rewards.
# The subsequent decrease and stabilization of the total reward around episode 600 could be a result of two factors:
# Exploitation: As the epsilon value decreases, the algorithm starts to exploit its learned knowledge more than exploring random actions. This could lead to a decrease in total reward if the environment is complex and the algorithm has not fully learned the optimal policy yet.
#
# Convergence: The algorithm might have learned an optimal (or near-optimal) policy for the environment, and is consistently applying this policy. This would result in a stable total reward over episodes. If the curve plateaus or flattens out, it suggests that the agent’s performance has stabilized and it has likely learned a policy that is close to optimal. This means the agent has found a strategy that works well and isn’t finding many new ways to improve.
#
#
# An upward trend in the curve indicates that the agent is learning and improving its performance over time. This is a good sign that the agent is effectively learning from its experiences.
#
# High variance or lots of ups and downs in the curve can indicate that the learning process is unstable. This could be due to various factors, such as a high learning rate causing drastic updates, or the exploration rate leading to inconsistent behavior.

# %% [markdown]
# # CNN and pytorch
#
# ## Exersice 3.1
#
# Now that we've gained a solid understanding of how neural networks function and how they are trained, we'll shift our focus to tackling an image classification problem. In this instance, we will utilize ready-made packages and libraries to streamline the process.
#
# Debugging neural networks is not an easy task! If you're looking for a helpful resource, the University of Amsterdam's course on debugging neural networks might provide valuable insights and techniques to address common challenges. https://uvadlc-notebooks.readthedocs.io/en/latest/tutorial_notebooks/guide3/Debugging_PyTorch.html
#
# The starting initial code is based on https://pytorch.org/tutorials/beginner/basics/quickstart_tutorial.html
#
# We are going to use the MNIST data set, which containts images of handwritten numbers and your task is to classify the written numbers from the images.
#
# Your task is to modify the code below to increase the accuracy to atleast 98%. There will hints written throughout below. Then in task 3.2 you will describe the changes you made and try to motivate why you made them.

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import torch.nn.functional as F

# %%
# Download training data from open datasets.
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# visualize the data
num_images_to_plot = 9
fig, axes = plt.subplots(3, 3, figsize=(8, 8))

for i in range(num_images_to_plot):
    image, label = training_data[i]
    ax = axes[i // 3, i % 3]
    ax.imshow(image.squeeze(), cmap='gray')
    ax.set_title(f"Label: {label}")
    ax.axis('off')

plt.show()

# %%
# Batch size, this is something you can tune, but the current value is decent.  
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# ## Define the neural network
#
# Here there is alot of things that can be tuned, I do encurage to add convolutional layers. While it is not neccessary to achive the accuracy, the convolutional layers are very good at images. For example a convolution layer can be defnined as following
#
# self.conv1 = nn.Conv2d(1, 3, 5)
#
# where the first input is the number of in channels. For a grey image there is only one channel, for an rgb image there is 3 channels. The second input is the number of out channels, you can see it as parrallel filters. The last input is the filter size. More infromation exists at https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html. The thing to keep in mind is the dimensions out of convolution. In this case the inpout is 1x28x28 and the output 3x24x24.
#
# In the forward funciton it can be used as
#
# x =  F.relu(self.conv1(x))
#
# And lets say you have defined a linear (dense) layer
#
# self.fd1 = nn.Linear(3 * 24 * 24, 120)
#
# They can be combined in the forward function as:
#
# x =  F.relu(self.conv1(x))
#
# x = torch.flatten(x, 1) # this flattens the output to a vector
#
# x =  F.relu(self.fd1(x))
#
#
# A lot of things can be modified here, such as number of layers, the size of the layers, the type of layers.

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

# Define the neural network model
class NeuralNetwork_pytorch(nn.Module):
    def __init__(self):
        super(NeuralNetwork_pytorch, self).__init__()#Modified
        # Define the convolutional layers   
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0),
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        )
        
        # Define the fully connected layers
        self.fd1 = nn.Linear(64 * 7 * 7, 512)  #Modified
        self.fd2 = nn.Linear(512, 128)
        self.fd3 = nn.Linear(128, 10)

    def forward(self, x): #Modified
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.fd1(x))
        x = F.relu(self.fd2(x))
        x = self.fd3(x)
        return x

model = NeuralNetwork_pytorch().to(device)
print(model)
# Out:
# Using cpu device
# NeuralNetwork_pytorch(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fd1): Linear(in_features=3136, out_features=512, bias=True)
#   (fd2): Linear(in_features=512, out_features=128, bias=True)
#   (fd3): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Our traning function, nothing to modify here
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % (100*int(64/batch_size)) == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
# our test function, nothing to modify here.
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
##Here


# The training loop, here you can change the optimizer, the opimizer is how you update the weights. SGD does 
# gradient decent. Adam optimizer adds some extra steps and regularization. 

epochs = 5 # try to not change the number of epochs, we want something that learns fast. 
           # One epoch trains through all the data. 
    
model = NeuralNetwork_pytorch().to(device)
loss_fn = nn.CrossEntropyLoss() # you can change the loss function 

# you can change the optimizer. The optimizer is how you updates the weights and there are differnet ways to do that.
# For more info see https://uvadlc-notebooks.readthedocs.io/en/latest/tutorial_notebooks/tutorial4/Optimization_and_Initialization.html#Optimization
#optimizer = torch.optim.SGD(model.parameters(), lr=1e-2)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.299349  [   64/60000]
# loss: 0.184100  [ 6464/60000]
# loss: 0.141063  [12864/60000]
# loss: 0.105327  [19264/60000]
# loss: 0.097257  [25664/60000]
# loss: 0.048426  [32064/60000]
# loss: 0.087027  [38464/60000]
# loss: 0.119899  [44864/60000]
# loss: 0.206964  [51264/60000]
# loss: 0.059079  [57664/60000]
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.081012
#
# Epoch 2
# -------------------------------
# loss: 0.028882  [   64/60000]
# loss: 0.098877  [ 6464/60000]
# loss: 0.028459  [12864/60000]
# loss: 0.010961  [19264/60000]
# loss: 0.014452  [25664/60000]
# loss: 0.037605  [32064/60000]
# loss: 0.062507  [38464/60000]
# loss: 0.025204  [44864/60000]
# loss: 0.088552  [51264/60000]
# loss: 0.018743  [57664/60000]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.033446
#
# Epoch 3
# -------------------------------
# loss: 0.038995  [   64/60000]
# loss: 0.029713  [ 6464/60000]
# loss: 0.026600  [12864/60000]
# loss: 0.016389  [19264/60000]
# loss: 0.009454  [25664/60000]
# loss: 0.012193  [32064/60000]
# loss: 0.025102  [38464/60000]
# loss: 0.021386  [44864/60000]
# loss: 0.062908  [51264/60000]
# loss: 0.013272  [57664/60000]
# Test Error:
#  Accuracy: 98.9%, Avg loss: 0.035725
#
# Epoch 4
# -------------------------------
# loss: 0.002141  [   64/60000]
# loss: 0.018716  [ 6464/60000]
# loss: 0.016504  [12864/60000]
# loss: 0.001301  [19264/60000]
# loss: 0.100002  [25664/60000]
# loss: 0.015391  [32064/60000]
# loss: 0.020694  [38464/60000]
# loss: 0.007176  [44864/60000]
# loss: 0.101657  [51264/60000]
# loss: 0.034244  [57664/60000]
# Test Error:
#  Accuracy: 98.9%, Avg loss: 0.036854
#
# Epoch 5
# -------------------------------
# loss: 0.003663  [   64/60000]
# loss: 0.033804  [ 6464/60000]
# loss: 0.002081  [12864/60000]
# loss: 0.126561  [19264/60000]
# loss: 0.000486  [25664/60000]
# loss: 0.006983  [32064/60000]
# loss: 0.024352  [38464/60000]
# loss: 0.018179  [44864/60000]
# loss: 0.137546  [51264/60000]
# loss: 0.002625  [57664/60000]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.046749
#
# Done!

# %% [markdown]
# ## Exersice 3.2: modifications
#
# What modifications did you do and what improvments did you see from them. Can you reason to why they worked?

# %% [markdown]
# Modifications:
# 1)- Convolutional layers: n the modified code, you’ve added two convolutional layers at the beginning of the network. Each convolutional layer is followed by a ReLU activation function and a max pooling operation. Convolutional layers are particularly effective for image processing tasks because they can capture local features in the image, such as edges, corners, and textures. The max pooling operation reduces the spatial dimensions of the output, which helps to make the network invariant to small translations in the input.
#
# * The first convolutional layer has 32 filters nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2)
#
# * The second convolutional layer has 64 filters. nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2) This layer can learn more complex patterns that consist of those basic features which habe been captured by the first layer
#
# 2)- Max pooling: We added max pooling after each convolutional layer for the downsampling by a factor of 2 . It helps to make the network invariant to small translations in the input.
#
# 3)- Flattening: The 2d feature map (output) is flattened into a one-dimensional vector before being passed to the fully connected layers.
#
# 4)- Fully connected Layers: The structure of the fully connected layers remains the same, but the input size to the first fully connected layer has changed. In the original code, the input size was 28*28, corresponding to the size of the input images. In the modified code, the input size is 64*7*7, which corresponds to the output size of the last convolutional layer.
#
# 5)-Forward Propagation: The forward propagation method has been updated to include the convolutional layers. The input is first passed through the convolutional layers, and the output is then flattened before being passed through the fully connected layers.
#
# 6)- Changing the epsilon number from 500 to 1000 in your code would typically affect the exploration-exploitation trade-off if we are  implementing a reinforcement learning algorithm such as Q-learning.
#
# we decided to increase the number of episodes from 500 to 1000 in my reinforcement learning model. This means that the model gets to learn from more sequences of actions, which  lead to better performance since we did not achived the results untill we increased the episodes to 1000. The idea is that with more episodes, the model might discover more optimal actions or strategies.
# But there’s a trade-off. While more episodes could lead to better performance, it could also slow down the learning process. Why? Because the model needs to process more episodes, and that takes time.
#
# Improvements:
#
# 1)-The addition of convolutional layers and max pooling operations has likely improved the performance of the network on image classification tasks. Here’s why:
#
# 2)-Convolutional layers learn hierarchical feature representations, which are highly effective for visual tasks. Deep networks with multiple layers of convolutions can learn features with increasing levels of abstraction, which helps in recognizing complex patterns.
#
# 3)-Max pooling reduces the spatial dimensions of the feature maps, making the network more computationally efficient and invariant to small translations.
#
# 4)-By using these layers, the network has become more specialized in handling image data and can now learn more complex patterns with fewer parameters, leading to better performance.
